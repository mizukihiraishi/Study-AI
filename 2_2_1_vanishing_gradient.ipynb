# %% [markdown]
# # 準備

# %% [markdown]
# ## Googleドライブのマウント

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## sys.pathの設定

# %% [markdown]
# 以下では，Googleドライブのマイドライブ直下にDNN_codeフォルダを置くことを仮定しています．必要に応じて，パスを変更してください．

# %%
import sys
sys.path.append('/content/drive/My Drive/DNN_code')

# %% [markdown]
# # vanishing gradient

# %% [markdown]
# ## sigmoid - gauss

# %%
import numpy as np
from common import layers
from collections import OrderedDict
from common import functions
from data.mnist import load_mnist
import matplotlib.pyplot as plt

# mnistをロード
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)
train_size = len(x_train)

print("データ読み込み完了")

# 重み初期値補正係数
wieght_init = 0.01
#入力層サイズ
input_layer_size = 784
#中間層サイズ
hidden_layer_1_size = 40
hidden_layer_2_size = 20

#出力層サイズ
output_layer_size = 10
# 繰り返し数
iters_num = 2000
# ミニバッチサイズ
batch_size = 100
# 学習率
learning_rate = 0.1
# 描写頻度
plot_interval=10

# 初期設定
def init_network():
    network = {} 
    network['W1'] = wieght_init * np.random.randn(input_layer_size, hidden_layer_1_size)
    network['W2'] = wieght_init * np.random.randn(hidden_layer_1_size, hidden_layer_2_size)
    network['W3'] = wieght_init * np.random.randn(hidden_layer_2_size, output_layer_size)

    network['b1'] = np.zeros(hidden_layer_1_size)
    network['b2'] = np.zeros(hidden_layer_2_size)
    network['b3'] = np.zeros(output_layer_size)

    return network

# 順伝播
def forward(network, x):
    W1, W2, W3 = network['W1'], network['W2'], network['W3']
    b1, b2, b3 = network['b1'], network['b2'], network['b3']
    hidden_f = functions.sigmoid
    
    u1 =  np.dot(x, W1) + b1
    z1 = hidden_f(u1)
    u2 =  np.dot(z1, W2) + b2
    z2 = hidden_f(u2)
    u3 =  np.dot(z2, W3) + b3
    y = functions.softmax(u3)
 
    return z1, z2, y

# 誤差逆伝播
def backward(x, d, z1, z2, y):
    grad = {}
    
    W1, W2, W3 = network['W1'], network['W2'], network['W3']
    b1, b2, b3 = network['b1'], network['b2'], network['b3']
    hidden_d_f = functions.d_sigmoid
    last_d_f = functions.d_softmax_with_loss
    
    
    # 出力層でのデルタ
    delta3 = last_d_f(d, y)
    # b3の勾配
    grad['b3'] = np.sum(delta3, axis=0)
    # W3の勾配
    grad['W3'] = np.dot(z2.T, delta3)
    # 2層でのデルタ
    delta2 = np.dot(delta3, W3.T) * hidden_d_f(z2)
    # b2の勾配
    grad['b2'] = np.sum(delta2, axis=0)
    # W2の勾配
    grad['W2'] = np.dot(z1.T, delta2)
    # 1層でのデルタ
    delta1 = np.dot(delta2, W2.T) * hidden_d_f(z1)
    # b1の勾配
    grad['b1'] = np.sum(delta1, axis=0)
    # W1の勾配
    grad['W1'] = np.dot(x.T, delta1)

    return grad

# パラメータの初期化
network = init_network()

accuracies_train = []
accuracies_test = []

# 正答率
def accuracy(x, d):
    z1, z2, y = forward(network, x)
    y = np.argmax(y, axis=1)
    if d.ndim != 1 : d = np.argmax(d, axis=1)
    accuracy = np.sum(y == d) / float(x.shape[0])
    return accuracy

for i in range(iters_num):
    # ランダムにバッチを取得    
    batch_mask = np.random.choice(train_size, batch_size)
    # ミニバッチに対応する教師訓練画像データを取得    
    x_batch = x_train[batch_mask]
    # ミニバッチに対応する訓練正解ラベルデータを取得する
    d_batch = d_train[batch_mask]


    
    z1, z2, y = forward(network, x_batch)
    grad = backward(x_batch, d_batch, z1, z2, y)

    if (i+1)%plot_interval==0:
        accr_test = accuracy(x_test, d_test)
        accuracies_test.append(accr_test)
        
        accr_train = accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)

        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))

    # パラメータに勾配適用
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network[key]  -= learning_rate * grad[key]


lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.1
#                 : 10. 正答率(テスト) = 0.0958
# Generation: 20. 正答率(トレーニング) = 0.16
#                 : 20. 正答率(テスト) = 0.1135
# Generation: 30. 正答率(トレーニング) = 0.07
#                 : 30. 正答率(テスト) = 0.1135
# Generation: 40. 正答率(トレーニング) = 0.09
#                 : 40. 正答率(テスト) = 0.098
# Generation: 50. 正答率(トレーニング) = 0.06
#                 : 50. 正答率(テスト) = 0.098
# Generation: 60. 正答率(トレーニング) = 0.05
#                 : 60. 正答率(テスト) = 0.1135
# Generation: 70. 正答率(トレーニング) = 0.1
#                 : 70. 正答率(テスト) = 0.1135
# Generation: 80. 正答率(トレーニング) = 0.11
#                 : 80. 正答率(テスト) = 0.1135
# Generation: 90. 正答率(トレーニング) = 0.06
#                 : 90. 正答率(テスト) = 0.1135
# Generation: 100. 正答率(トレーニング) = 0.13
#                 : 100. 正答率(テスト) = 0.1135
# Generation: 110. 正答率(トレーニング) = 0.1
#                 : 110. 正答率(テスト) = 0.1135
# Generation: 120. 正答率(トレーニング) = 0.09
#                 : 120. 正答率(テスト) = 0.1135
# Generation: 130. 正答率(トレーニング) = 0.09
#                 : 130. 正答率(テスト) = 0.1135
# Generation: 140. 正答率(トレーニング) = 0.11
#                 : 140. 正答率(テスト) = 0.1135
# Generation: 150. 正答率(トレーニング) = 0.12
#                 : 150. 正答率(テスト) = 0.1135
# Generation: 160. 正答率(トレーニング) = 0.12
#                 : 160. 正答率(テスト) = 0.1135
# Generation: 170. 正答率(トレーニング) = 0.09
#                 : 170. 正答率(テスト) = 0.1028
# Generation: 180. 正答率(トレーニング) = 0.1
#                 : 180. 正答率(テスト) = 0.1135
# Generation: 190. 正答率(トレーニング) = 0.08
#                 : 190. 正答率(テスト) = 0.1135
# Generation: 200. 正答率(トレーニング) = 0.11
#                 : 200. 正答率(テスト) = 0.1135
# Generation: 210. 正答率(トレーニング) = 0.14
#                 : 210. 正答率(テスト) = 0.1135
# Generation: 220. 正答率(トレーニング) = 0.12
#                 : 220. 正答率(テスト) = 0.1028
# Generation: 230. 正答率(トレーニング) = 0.08
#                 : 230. 正答率(テスト) = 0.1028
# Generation: 240. 正答率(トレーニング) = 0.09
#                 : 240. 正答率(テスト) = 0.1032
# Generation: 250. 正答率(トレーニング) = 0.08
#                 : 250. 正答率(テスト) = 0.1028
# Generation: 260. 正答率(トレーニング) = 0.19
#                 : 260. 正答率(テスト) = 0.1135
# Generation: 270. 正答率(トレーニング) = 0.16
#                 : 270. 正答率(テスト) = 0.1135
# Generation: 280. 正答率(トレーニング) = 0.1
#                 : 280. 正答率(テスト) = 0.1135
# Generation: 290. 正答率(トレーニング) = 0.14
#                 : 290. 正答率(テスト) = 0.1135
# Generation: 300. 正答率(トレーニング) = 0.17
#                 : 300. 正答率(テスト) = 0.1135
# Generation: 310. 正答率(トレーニング) = 0.13
#                 : 310. 正答率(テスト) = 0.1135
# Generation: 320. 正答率(トレーニング) = 0.08
#                 : 320. 正答率(テスト) = 0.101
# Generation: 330. 正答率(トレーニング) = 0.1
#                 : 330. 正答率(テスト) = 0.101
# Generation: 340. 正答率(トレーニング) = 0.13
#                 : 340. 正答率(テスト) = 0.1135
# Generation: 350. 正答率(トレーニング) = 0.06
#                 : 350. 正答率(テスト) = 0.1135
# Generation: 360. 正答率(トレーニング) = 0.09
#                 : 360. 正答率(テスト) = 0.1135
# Generation: 370. 正答率(トレーニング) = 0.14
#                 : 370. 正答率(テスト) = 0.1135
# Generation: 380. 正答率(トレーニング) = 0.1
#                 : 380. 正答率(テスト) = 0.1135
# Generation: 390. 正答率(トレーニング) = 0.1
#                 : 390. 正答率(テスト) = 0.1135
# Generation: 400. 正答率(トレーニング) = 0.06
#                 : 400. 正答率(テスト) = 0.1135
# Generation: 410. 正答率(トレーニング) = 0.07
#                 : 410. 正答率(テスト) = 0.1028
# Generation: 420. 正答率(トレーニング) = 0.09
#                 : 420. 正答率(テスト) = 0.098
# Generation: 430. 正答率(トレーニング) = 0.08
#                 : 430. 正答率(テスト) = 0.1135
# Generation: 440. 正答率(トレーニング) = 0.09
#                 : 440. 正答率(テスト) = 0.1135
# Generation: 450. 正答率(トレーニング) = 0.14
#                 : 450. 正答率(テスト) = 0.1135
# Generation: 460. 正答率(トレーニング) = 0.1
#                 : 460. 正答率(テスト) = 0.098
# Generation: 470. 正答率(トレーニング) = 0.11
#                 : 470. 正答率(テスト) = 0.1135
# Generation: 480. 正答率(トレーニング) = 0.08
#                 : 480. 正答率(テスト) = 0.1135
# Generation: 490. 正答率(トレーニング) = 0.11
#                 : 490. 正答率(テスト) = 0.1135
# Generation: 500. 正答率(トレーニング) = 0.12
#                 : 500. 正答率(テスト) = 0.1135
# Generation: 510. 正答率(トレーニング) = 0.09
#                 : 510. 正答率(テスト) = 0.1135
# Generation: 520. 正答率(トレーニング) = 0.07
#                 : 520. 正答率(テスト) = 0.1028
# Generation: 530. 正答率(トレーニング) = 0.15
#                 : 530. 正答率(テスト) = 0.1028
# Generation: 540. 正答率(トレーニング) = 0.19
#                 : 540. 正答率(テスト) = 0.1028
# Generation: 550. 正答率(トレーニング) = 0.1
#                 : 550. 正答率(テスト) = 0.1028
# Generation: 560. 正答率(トレーニング) = 0.1
#                 : 560. 正答率(テスト) = 0.1009
# Generation: 570. 正答率(トレーニング) = 0.11
#                 : 570. 正答率(テスト) = 0.1135
# Generation: 580. 正答率(トレーニング) = 0.02
#                 : 580. 正答率(テスト) = 0.1032
# Generation: 590. 正答率(トレーニング) = 0.09
#                 : 590. 正答率(テスト) = 0.1135
# Generation: 600. 正答率(トレーニング) = 0.1
#                 : 600. 正答率(テスト) = 0.1135
# Generation: 610. 正答率(トレーニング) = 0.06
#                 : 610. 正答率(テスト) = 0.098
# Generation: 620. 正答率(トレーニング) = 0.07
#                 : 620. 正答率(テスト) = 0.1135
# Generation: 630. 正答率(トレーニング) = 0.07
#                 : 630. 正答率(テスト) = 0.1135
# Generation: 640. 正答率(トレーニング) = 0.11
#                 : 640. 正答率(テスト) = 0.1135
# Generation: 650. 正答率(トレーニング) = 0.1
#                 : 650. 正答率(テスト) = 0.1135
# Generation: 660. 正答率(トレーニング) = 0.08
#                 : 660. 正答率(テスト) = 0.1135
# Generation: 670. 正答率(トレーニング) = 0.13
#                 : 670. 正答率(テスト) = 0.1032
# Generation: 680. 正答率(トレーニング) = 0.06
#                 : 680. 正答率(テスト) = 0.1135
# Generation: 690. 正答率(トレーニング) = 0.07
#                 : 690. 正答率(テスト) = 0.1135
# Generation: 700. 正答率(トレーニング) = 0.12
#                 : 700. 正答率(テスト) = 0.1135
# Generation: 710. 正答率(トレーニング) = 0.14
#                 : 710. 正答率(テスト) = 0.101
# Generation: 720. 正答率(トレーニング) = 0.1
#                 : 720. 正答率(テスト) = 0.1135
# Generation: 730. 正答率(トレーニング) = 0.13
#                 : 730. 正答率(テスト) = 0.1135
# Generation: 740. 正答率(トレーニング) = 0.07
#                 : 740. 正答率(テスト) = 0.1135
# Generation: 750. 正答率(トレーニング) = 0.11
#                 : 750. 正答率(テスト) = 0.0958
# Generation: 760. 正答率(トレーニング) = 0.15
#                 : 760. 正答率(テスト) = 0.1135
# Generation: 770. 正答率(トレーニング) = 0.09
#                 : 770. 正答率(テスト) = 0.1135
# Generation: 780. 正答率(トレーニング) = 0.08
#                 : 780. 正答率(テスト) = 0.1135
# Generation: 790. 正答率(トレーニング) = 0.14
#                 : 790. 正答率(テスト) = 0.1135
# Generation: 800. 正答率(トレーニング) = 0.06
#                 : 800. 正答率(テスト) = 0.1028
# Generation: 810. 正答率(トレーニング) = 0.15
#                 : 810. 正答率(テスト) = 0.1135
# Generation: 820. 正答率(トレーニング) = 0.14
#                 : 820. 正答率(テスト) = 0.1135
# Generation: 830. 正答率(トレーニング) = 0.2
#                 : 830. 正答率(テスト) = 0.1135
# Generation: 840. 正答率(トレーニング) = 0.11
#                 : 840. 正答率(テスト) = 0.1135
# Generation: 850. 正答率(トレーニング) = 0.16
#                 : 850. 正答率(テスト) = 0.1135
# Generation: 860. 正答率(トレーニング) = 0.1
#                 : 860. 正答率(テスト) = 0.1135
# Generation: 870. 正答率(トレーニング) = 0.07
#                 : 870. 正答率(テスト) = 0.1135
# Generation: 880. 正答率(トレーニング) = 0.16
#                 : 880. 正答率(テスト) = 0.1135
# Generation: 890. 正答率(トレーニング) = 0.17
#                 : 890. 正答率(テスト) = 0.1135
# Generation: 900. 正答率(トレーニング) = 0.1
#                 : 900. 正答率(テスト) = 0.1135
# Generation: 910. 正答率(トレーニング) = 0.14
#                 : 910. 正答率(テスト) = 0.1135
# Generation: 920. 正答率(トレーニング) = 0.18
#                 : 920. 正答率(テスト) = 0.1135
# Generation: 930. 正答率(トレーニング) = 0.09
#                 : 930. 正答率(テスト) = 0.1135
# Generation: 940. 正答率(トレーニング) = 0.08
#                 : 940. 正答率(テスト) = 0.1135
# Generation: 950. 正答率(トレーニング) = 0.12
#                 : 950. 正答率(テスト) = 0.1135
# Generation: 960. 正答率(トレーニング) = 0.1
#                 : 960. 正答率(テスト) = 0.1135
# Generation: 970. 正答率(トレーニング) = 0.11
#                 : 970. 正答率(テスト) = 0.1135
# Generation: 980. 正答率(トレーニング) = 0.05
#                 : 980. 正答率(テスト) = 0.1135
# Generation: 990. 正答率(トレーニング) = 0.15
#                 : 990. 正答率(テスト) = 0.1135
# Generation: 1000. 正答率(トレーニング) = 0.07
#                 : 1000. 正答率(テスト) = 0.1135
# Generation: 1010. 正答率(トレーニング) = 0.12
#                 : 1010. 正答率(テスト) = 0.1135
# Generation: 1020. 正答率(トレーニング) = 0.14
#                 : 1020. 正答率(テスト) = 0.1135
# Generation: 1030. 正答率(トレーニング) = 0.13
#                 : 1030. 正答率(テスト) = 0.101
# Generation: 1040. 正答率(トレーニング) = 0.08
#                 : 1040. 正答率(テスト) = 0.1135
# Generation: 1050. 正答率(トレーニング) = 0.1
#                 : 1050. 正答率(テスト) = 0.101
# Generation: 1060. 正答率(トレーニング) = 0.09
#                 : 1060. 正答率(テスト) = 0.1135
# Generation: 1070. 正答率(トレーニング) = 0.08
#                 : 1070. 正答率(テスト) = 0.1135
# Generation: 1080. 正答率(トレーニング) = 0.12
#                 : 1080. 正答率(テスト) = 0.1135
# Generation: 1090. 正答率(トレーニング) = 0.17
#                 : 1090. 正答率(テスト) = 0.1135
# Generation: 1100. 正答率(トレーニング) = 0.11
#                 : 1100. 正答率(テスト) = 0.1135
# Generation: 1110. 正答率(トレーニング) = 0.06
#                 : 1110. 正答率(テスト) = 0.098
# Generation: 1120. 正答率(トレーニング) = 0.12
#                 : 1120. 正答率(テスト) = 0.1028
# Generation: 1130. 正答率(トレーニング) = 0.11
#                 : 1130. 正答率(テスト) = 0.0958
# Generation: 1140. 正答率(トレーニング) = 0.09
#                 : 1140. 正答率(テスト) = 0.1009
# Generation: 1150. 正答率(トレーニング) = 0.11
#                 : 1150. 正答率(テスト) = 0.1135
# Generation: 1160. 正答率(トレーニング) = 0.09
#                 : 1160. 正答率(テスト) = 0.1135
# Generation: 1170. 正答率(トレーニング) = 0.1
#                 : 1170. 正答率(テスト) = 0.1135
# Generation: 1180. 正答率(トレーニング) = 0.12
#                 : 1180. 正答率(テスト) = 0.1028
# Generation: 1190. 正答率(トレーニング) = 0.12
#                 : 1190. 正答率(テスト) = 0.1135
# Generation: 1200. 正答率(トレーニング) = 0.11
#                 : 1200. 正答率(テスト) = 0.1135
# Generation: 1210. 正答率(トレーニング) = 0.12
#                 : 1210. 正答率(テスト) = 0.1028
# Generation: 1220. 正答率(トレーニング) = 0.12
#                 : 1220. 正答率(テスト) = 0.1135
# Generation: 1230. 正答率(トレーニング) = 0.11
#                 : 1230. 正答率(テスト) = 0.1135
# Generation: 1240. 正答率(トレーニング) = 0.12
#                 : 1240. 正答率(テスト) = 0.1135
# Generation: 1250. 正答率(トレーニング) = 0.03
#                 : 1250. 正答率(テスト) = 0.1135
# Generation: 1260. 正答率(トレーニング) = 0.12
#                 : 1260. 正答率(テスト) = 0.1135
# Generation: 1270. 正答率(トレーニング) = 0.13
#                 : 1270. 正答率(テスト) = 0.1135
# Generation: 1280. 正答率(トレーニング) = 0.07
#                 : 1280. 正答率(テスト) = 0.1135
# Generation: 1290. 正答率(トレーニング) = 0.12
#                 : 1290. 正答率(テスト) = 0.098
# Generation: 1300. 正答率(トレーニング) = 0.11
#                 : 1300. 正答率(テスト) = 0.098
# Generation: 1310. 正答率(トレーニング) = 0.06
#                 : 1310. 正答率(テスト) = 0.1028
# Generation: 1320. 正答率(トレーニング) = 0.15
#                 : 1320. 正答率(テスト) = 0.101
# Generation: 1330. 正答率(トレーニング) = 0.11
#                 : 1330. 正答率(テスト) = 0.101
# Generation: 1340. 正答率(トレーニング) = 0.11
#                 : 1340. 正答率(テスト) = 0.101
# Generation: 1350. 正答率(トレーニング) = 0.04
#                 : 1350. 正答率(テスト) = 0.101
# Generation: 1360. 正答率(トレーニング) = 0.08
#                 : 1360. 正答率(テスト) = 0.1135
# Generation: 1370. 正答率(トレーニング) = 0.11
#                 : 1370. 正答率(テスト) = 0.1135
# Generation: 1380. 正答率(トレーニング) = 0.05
#                 : 1380. 正答率(テスト) = 0.1135
# Generation: 1390. 正答率(トレーニング) = 0.1
#                 : 1390. 正答率(テスト) = 0.1135
# Generation: 1400. 正答率(トレーニング) = 0.12
#                 : 1400. 正答率(テスト) = 0.1135
# Generation: 1410. 正答率(トレーニング) = 0.13
#                 : 1410. 正答率(テスト) = 0.1028
# Generation: 1420. 正答率(トレーニング) = 0.09
#                 : 1420. 正答率(テスト) = 0.1028
# Generation: 1430. 正答率(トレーニング) = 0.12
#                 : 1430. 正答率(テスト) = 0.1028
# Generation: 1440. 正答率(トレーニング) = 0.13
#                 : 1440. 正答率(テスト) = 0.1135
# Generation: 1450. 正答率(トレーニング) = 0.09
#                 : 1450. 正答率(テスト) = 0.101
# Generation: 1460. 正答率(トレーニング) = 0.12
#                 : 1460. 正答率(テスト) = 0.1135
# Generation: 1470. 正答率(トレーニング) = 0.09
#                 : 1470. 正答率(テスト) = 0.1135
# Generation: 1480. 正答率(トレーニング) = 0.08
#                 : 1480. 正答率(テスト) = 0.1135
# Generation: 1490. 正答率(トレーニング) = 0.11
#                 : 1490. 正答率(テスト) = 0.101
# Generation: 1500. 正答率(トレーニング) = 0.14
#                 : 1500. 正答率(テスト) = 0.1135
# Generation: 1510. 正答率(トレーニング) = 0.06
#                 : 1510. 正答率(テスト) = 0.1135
# Generation: 1520. 正答率(トレーニング) = 0.11
#                 : 1520. 正答率(テスト) = 0.1028
# Generation: 1530. 正答率(トレーニング) = 0.21
#                 : 1530. 正答率(テスト) = 0.1576
# Generation: 1540. 正答率(トレーニング) = 0.13
#                 : 1540. 正答率(テスト) = 0.1135
# Generation: 1550. 正答率(トレーニング) = 0.11
#                 : 1550. 正答率(テスト) = 0.1135
# Generation: 1560. 正答率(トレーニング) = 0.11
#                 : 1560. 正答率(テスト) = 0.1135
# Generation: 1570. 正答率(トレーニング) = 0.07
#                 : 1570. 正答率(テスト) = 0.0974
# Generation: 1580. 正答率(トレーニング) = 0.06
#                 : 1580. 正答率(テスト) = 0.0974
# Generation: 1590. 正答率(トレーニング) = 0.08
#                 : 1590. 正答率(テスト) = 0.101
# Generation: 1600. 正答率(トレーニング) = 0.14
#                 : 1600. 正答率(テスト) = 0.1032
# Generation: 1610. 正答率(トレーニング) = 0.12
#                 : 1610. 正答率(テスト) = 0.1028
# Generation: 1620. 正答率(トレーニング) = 0.12
#                 : 1620. 正答率(テスト) = 0.1028
# Generation: 1630. 正答率(トレーニング) = 0.08
#                 : 1630. 正答率(テスト) = 0.1032
# Generation: 1640. 正答率(トレーニング) = 0.08
#                 : 1640. 正答率(テスト) = 0.1032
# Generation: 1650. 正答率(トレーニング) = 0.11
#                 : 1650. 正答率(テスト) = 0.1135
# Generation: 1660. 正答率(トレーニング) = 0.07
#                 : 1660. 正答率(テスト) = 0.1135
# Generation: 1670. 正答率(トレーニング) = 0.13
#                 : 1670. 正答率(テスト) = 0.1032
# Generation: 1680. 正答率(トレーニング) = 0.15
#                 : 1680. 正答率(テスト) = 0.1032
# Generation: 1690. 正答率(トレーニング) = 0.09
#                 : 1690. 正答率(テスト) = 0.1135
# Generation: 1700. 正答率(トレーニング) = 0.19
#                 : 1700. 正答率(テスト) = 0.1135
# Generation: 1710. 正答率(トレーニング) = 0.06
#                 : 1710. 正答率(テスト) = 0.1028
# Generation: 1720. 正答率(トレーニング) = 0.09
#                 : 1720. 正答率(テスト) = 0.1135
# Generation: 1730. 正答率(トレーニング) = 0.17
#                 : 1730. 正答率(テスト) = 0.1135
# Generation: 1740. 正答率(トレーニング) = 0.1
#                 : 1740. 正答率(テスト) = 0.1135
# Generation: 1750. 正答率(トレーニング) = 0.11
#                 : 1750. 正答率(テスト) = 0.0958
# Generation: 1760. 正答率(トレーニング) = 0.05
#                 : 1760. 正答率(テスト) = 0.1135
# Generation: 1770. 正答率(トレーニング) = 0.09
#                 : 1770. 正答率(テスト) = 0.1135
# Generation: 1780. 正答率(トレーニング) = 0.08
#                 : 1780. 正答率(テスト) = 0.1135
# Generation: 1790. 正答率(トレーニング) = 0.06
#                 : 1790. 正答率(テスト) = 0.1028
# Generation: 1800. 正答率(トレーニング) = 0.11
#                 : 1800. 正答率(テスト) = 0.1028
# Generation: 1810. 正答率(トレーニング) = 0.13
#                 : 1810. 正答率(テスト) = 0.1135
# Generation: 1820. 正答率(トレーニング) = 0.08
#                 : 1820. 正答率(テスト) = 0.1135
# Generation: 1830. 正答率(トレーニング) = 0.14
#                 : 1830. 正答率(テスト) = 0.1135
# Generation: 1840. 正答率(トレーニング) = 0.1
#                 : 1840. 正答率(テスト) = 0.1135
# Generation: 1850. 正答率(トレーニング) = 0.18
#                 : 1850. 正答率(テスト) = 0.1009
# Generation: 1860. 正答率(トレーニング) = 0.1
#                 : 1860. 正答率(テスト) = 0.1009
# Generation: 1870. 正答率(トレーニング) = 0.12
#                 : 1870. 正答率(テスト) = 0.1009
# Generation: 1880. 正答率(トレーニング) = 0.13
#                 : 1880. 正答率(テスト) = 0.1009
# Generation: 1890. 正答率(トレーニング) = 0.08
#                 : 1890. 正答率(テスト) = 0.101
# Generation: 1900. 正答率(トレーニング) = 0.16
#                 : 1900. 正答率(テスト) = 0.1135
# Generation: 1910. 正答率(トレーニング) = 0.09
#                 : 1910. 正答率(テスト) = 0.1135
# Generation: 1920. 正答率(トレーニング) = 0.12
#                 : 1920. 正答率(テスト) = 0.1135
# Generation: 1930. 正答率(トレーニング) = 0.1
#                 : 1930. 正答率(テスト) = 0.1028
# Generation: 1940. 正答率(トレーニング) = 0.07
#                 : 1940. 正答率(テスト) = 0.1028
# Generation: 1950. 正答率(トレーニング) = 0.15
#                 : 1950. 正答率(テスト) = 0.1135
# Generation: 1960. 正答率(トレーニング) = 0.15
#                 : 1960. 正答率(テスト) = 0.1135
# Generation: 1970. 正答率(トレーニング) = 0.14
#                 : 1970. 正答率(テスト) = 0.1135
# Generation: 1980. 正答率(トレーニング) = 0.09
#                 : 1980. 正答率(テスト) = 0.1135
# Generation: 1990. 正答率(トレーニング) = 0.19
#                 : 1990. 正答率(テスト) = 0.1135
# Generation: 2000. 正答率(トレーニング) = 0.14
#                 : 2000. 正答率(テスト) = 0.1028

# %% [markdown]
# ## ReLU - gauss

# %%
import numpy as np
from data.mnist import load_mnist
from PIL import Image
import pickle
from common import functions
import matplotlib.pyplot as plt

# mnistをロード
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)
train_size = len(x_train)

print("データ読み込み完了")

# 重み初期値補正係数
wieght_init = 0.01
#入力層サイズ
input_layer_size = 784
#中間層サイズ
hidden_layer_1_size = 40
hidden_layer_2_size = 20

#出力層サイズ
output_layer_size = 10
# 繰り返し数
iters_num = 2000
# ミニバッチサイズ
batch_size = 100
# 学習率
learning_rate = 0.1
# 描写頻度
plot_interval=10

# 初期設定
def init_network():
    network = {} 

    network['W1'] = wieght_init * np.random.randn(input_layer_size, hidden_layer_1_size)
    network['W2'] = wieght_init * np.random.randn(hidden_layer_1_size, hidden_layer_2_size)
    network['W3'] = wieght_init * np.random.randn(hidden_layer_2_size, output_layer_size)
            
    network['b1'] = np.zeros(hidden_layer_1_size)
    network['b2'] = np.zeros(hidden_layer_2_size)
    network['b3'] = np.zeros(output_layer_size)

    return network

# 順伝播
def forward(network, x):
    W1, W2, W3 = network['W1'], network['W2'], network['W3']
    b1, b2, b3 = network['b1'], network['b2'], network['b3']
    
    ###########  変更箇所  ##############

    hidden_f = functions.relu

    #################################
    
    u1 =  np.dot(x, W1) + b1
    z1 = hidden_f(u1)
    u2 =  np.dot(z1, W2) + b2
    z2 = hidden_f(u2)
    u3 =  np.dot(z2, W3) + b3
    y = functions.softmax(u3)
 
    return z1, z2, y

# 誤差逆伝播
def backward(x, d, z1, z2, y):
    grad = {}
    
    W1, W2, W3 = network['W1'], network['W2'], network['W3']
    b1, b2, b3 = network['b1'], network['b2'], network['b3']

    ###########  変更箇所  ##############
    
    hidden_d_f = functions.d_relu
    
    #################################
    
    
    # 出力層でのデルタ
    delta3 = functions.d_softmax_with_loss(d, y)
    # b3の勾配
    grad['b3'] = np.sum(delta3, axis=0)
    # W3の勾配
    grad['W3'] = np.dot(z2.T, delta3)
    # 2層でのデルタ
    delta2 = np.dot(delta3, W3.T) * hidden_d_f(z2)
    # b2の勾配
    grad['b2'] = np.sum(delta2, axis=0)
    # W2の勾配
    grad['W2'] = np.dot(z1.T, delta2)
    # 1層でのデルタ
    delta1 = np.dot(delta2, W2.T) * hidden_d_f(z1)
    # b1の勾配
    grad['b1'] = np.sum(delta1, axis=0)
    # W1の勾配
    grad['W1'] = np.dot(x.T, delta1)

    return grad

# パラメータの初期化
network = init_network()

accuracies_train = []
accuracies_test = []

# 正答率
def accuracy(x, d):
    z1, z2, y = forward(network, x)
    y = np.argmax(y, axis=1)
    if d.ndim != 1 : d = np.argmax(d, axis=1)
    accuracy = np.sum(y == d) / float(x.shape[0])
    return accuracy

for i in range(iters_num):
    # ランダムにバッチを取得    
    batch_mask = np.random.choice(train_size, batch_size)
    # ミニバッチに対応する教師訓練画像データを取得    
    x_batch = x_train[batch_mask]
    # ミニバッチに対応する訓練正解ラベルデータを取得する
    d_batch = d_train[batch_mask]


    
    z1, z2, y = forward(network, x_batch)
    grad = backward(x_batch, d_batch, z1, z2, y)

    if (i+1)%plot_interval==0:
        accr_test = accuracy(x_test, d_test)
        accuracies_test.append(accr_test)
        
        accr_train = accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)

        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
        
    # パラメータに勾配適用
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network[key]  -= learning_rate * grad[key]


lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.08
#                 : 10. 正答率(テスト) = 0.0958
# Generation: 20. 正答率(トレーニング) = 0.1
#                 : 20. 正答率(テスト) = 0.1028
# Generation: 30. 正答率(トレーニング) = 0.13
#                 : 30. 正答率(テスト) = 0.1028
# Generation: 40. 正答率(トレーニング) = 0.07
#                 : 40. 正答率(テスト) = 0.1032
# Generation: 50. 正答率(トレーニング) = 0.1
#                 : 50. 正答率(テスト) = 0.1135
# Generation: 60. 正答率(トレーニング) = 0.12
#                 : 60. 正答率(テスト) = 0.1028
# Generation: 70. 正答率(トレーニング) = 0.13
#                 : 70. 正答率(テスト) = 0.1135
# Generation: 80. 正答率(トレーニング) = 0.11
#                 : 80. 正答率(テスト) = 0.1135
# Generation: 90. 正答率(トレーニング) = 0.19
#                 : 90. 正答率(テスト) = 0.1135
# Generation: 100. 正答率(トレーニング) = 0.09
#                 : 100. 正答率(テスト) = 0.1135
# Generation: 110. 正答率(トレーニング) = 0.07
#                 : 110. 正答率(テスト) = 0.1135
# Generation: 120. 正答率(トレーニング) = 0.18
#                 : 120. 正答率(テスト) = 0.1135
# Generation: 130. 正答率(トレーニング) = 0.1
#                 : 130. 正答率(テスト) = 0.1135
# Generation: 140. 正答率(トレーニング) = 0.18
#                 : 140. 正答率(テスト) = 0.1135
# Generation: 150. 正答率(トレーニング) = 0.1
#                 : 150. 正答率(テスト) = 0.1135
# Generation: 160. 正答率(トレーニング) = 0.17
#                 : 160. 正答率(テスト) = 0.1135
# Generation: 170. 正答率(トレーニング) = 0.16
#                 : 170. 正答率(テスト) = 0.1135
# Generation: 180. 正答率(トレーニング) = 0.16
#                 : 180. 正答率(テスト) = 0.1135
# Generation: 190. 正答率(トレーニング) = 0.09
#                 : 190. 正答率(テスト) = 0.1135
# Generation: 200. 正答率(トレーニング) = 0.07
#                 : 200. 正答率(テスト) = 0.1135
# Generation: 210. 正答率(トレーニング) = 0.11
#                 : 210. 正答率(テスト) = 0.1135
# Generation: 220. 正答率(トレーニング) = 0.09
#                 : 220. 正答率(テスト) = 0.1135
# Generation: 230. 正答率(トレーニング) = 0.18
#                 : 230. 正答率(テスト) = 0.1135
# Generation: 240. 正答率(トレーニング) = 0.07
#                 : 240. 正答率(テスト) = 0.1135
# Generation: 250. 正答率(トレーニング) = 0.15
#                 : 250. 正答率(テスト) = 0.1135
# Generation: 260. 正答率(トレーニング) = 0.09
#                 : 260. 正答率(テスト) = 0.1135
# Generation: 270. 正答率(トレーニング) = 0.12
#                 : 270. 正答率(テスト) = 0.1135
# Generation: 280. 正答率(トレーニング) = 0.12
#                 : 280. 正答率(テスト) = 0.1135
# Generation: 290. 正答率(トレーニング) = 0.11
#                 : 290. 正答率(テスト) = 0.1135
# Generation: 300. 正答率(トレーニング) = 0.1
#                 : 300. 正答率(テスト) = 0.1135
# Generation: 310. 正答率(トレーニング) = 0.11
#                 : 310. 正答率(テスト) = 0.1135
# Generation: 320. 正答率(トレーニング) = 0.11
#                 : 320. 正答率(テスト) = 0.1135
# Generation: 330. 正答率(トレーニング) = 0.11
#                 : 330. 正答率(テスト) = 0.1135
# Generation: 340. 正答率(トレーニング) = 0.1
#                 : 340. 正答率(テスト) = 0.1135
# Generation: 350. 正答率(トレーニング) = 0.14
#                 : 350. 正答率(テスト) = 0.1135
# Generation: 360. 正答率(トレーニング) = 0.14
#                 : 360. 正答率(テスト) = 0.1135
# Generation: 370. 正答率(トレーニング) = 0.14
#                 : 370. 正答率(テスト) = 0.1135
# Generation: 380. 正答率(トレーニング) = 0.07
#                 : 380. 正答率(テスト) = 0.1135
# Generation: 390. 正答率(トレーニング) = 0.04
#                 : 390. 正答率(テスト) = 0.1135
# Generation: 400. 正答率(トレーニング) = 0.12
#                 : 400. 正答率(テスト) = 0.1135
# Generation: 410. 正答率(トレーニング) = 0.16
#                 : 410. 正答率(テスト) = 0.1135
# Generation: 420. 正答率(トレーニング) = 0.11
#                 : 420. 正答率(テスト) = 0.1135
# Generation: 430. 正答率(トレーニング) = 0.15
#                 : 430. 正答率(テスト) = 0.1135
# Generation: 440. 正答率(トレーニング) = 0.12
#                 : 440. 正答率(テスト) = 0.1135
# Generation: 450. 正答率(トレーニング) = 0.12
#                 : 450. 正答率(テスト) = 0.1135
# Generation: 460. 正答率(トレーニング) = 0.17
#                 : 460. 正答率(テスト) = 0.1135
# Generation: 470. 正答率(トレーニング) = 0.07
#                 : 470. 正答率(テスト) = 0.1135
# Generation: 480. 正答率(トレーニング) = 0.1
#                 : 480. 正答率(テスト) = 0.1135
# Generation: 490. 正答率(トレーニング) = 0.08
#                 : 490. 正答率(テスト) = 0.1138
# Generation: 500. 正答率(トレーニング) = 0.15
#                 : 500. 正答率(テスト) = 0.1424
# Generation: 510. 正答率(トレーニング) = 0.19
#                 : 510. 正答率(テスト) = 0.1904
# Generation: 520. 正答率(トレーニング) = 0.33
#                 : 520. 正答率(テスト) = 0.2408
# Generation: 530. 正答率(トレーニング) = 0.27
#                 : 530. 正答率(テスト) = 0.2148
# Generation: 540. 正答率(トレーニング) = 0.18
#                 : 540. 正答率(テスト) = 0.2107
# Generation: 550. 正答率(トレーニング) = 0.15
#                 : 550. 正答率(テスト) = 0.2098
# Generation: 560. 正答率(トレーニング) = 0.19
#                 : 560. 正答率(テスト) = 0.2105
# Generation: 570. 正答率(トレーニング) = 0.27
#                 : 570. 正答率(テスト) = 0.2107
# Generation: 580. 正答率(トレーニング) = 0.23
#                 : 580. 正答率(テスト) = 0.2171
# Generation: 590. 正答率(トレーニング) = 0.18
#                 : 590. 正答率(テスト) = 0.2318
# Generation: 600. 正答率(トレーニング) = 0.27
#                 : 600. 正答率(テスト) = 0.245
# Generation: 610. 正答率(トレーニング) = 0.31
#                 : 610. 正答率(テスト) = 0.2569
# Generation: 620. 正答率(トレーニング) = 0.29
#                 : 620. 正答率(テスト) = 0.2749
# Generation: 630. 正答率(トレーニング) = 0.41
#                 : 630. 正答率(テスト) = 0.3174
# Generation: 640. 正答率(トレーニング) = 0.3
#                 : 640. 正答率(テスト) = 0.3136
# Generation: 650. 正答率(トレーニング) = 0.3
#                 : 650. 正答率(テスト) = 0.3341
# Generation: 660. 正答率(トレーニング) = 0.32
#                 : 660. 正答率(テスト) = 0.4044
# Generation: 670. 正答率(トレーニング) = 0.39
#                 : 670. 正答率(テスト) = 0.395
# Generation: 680. 正答率(トレーニング) = 0.35
#                 : 680. 正答率(テスト) = 0.4523
# Generation: 690. 正答率(トレーニング) = 0.61
#                 : 690. 正答率(テスト) = 0.551
# Generation: 700. 正答率(トレーニング) = 0.54
#                 : 700. 正答率(テスト) = 0.5666
# Generation: 710. 正答率(トレーニング) = 0.49
#                 : 710. 正答率(テスト) = 0.5305
# Generation: 720. 正答率(トレーニング) = 0.6
#                 : 720. 正答率(テスト) = 0.555
# Generation: 730. 正答率(トレーニング) = 0.57
#                 : 730. 正答率(テスト) = 0.5535
# Generation: 740. 正答率(トレーニング) = 0.49
#                 : 740. 正答率(テスト) = 0.5521
# Generation: 750. 正答率(トレーニング) = 0.58
#                 : 750. 正答率(テスト) = 0.5655
# Generation: 760. 正答率(トレーニング) = 0.62
#                 : 760. 正答率(テスト) = 0.6175
# Generation: 770. 正答率(トレーニング) = 0.67
#                 : 770. 正答率(テスト) = 0.6093
# Generation: 780. 正答率(トレーニング) = 0.58
#                 : 780. 正答率(テスト) = 0.6271
# Generation: 790. 正答率(トレーニング) = 0.61
#                 : 790. 正答率(テスト) = 0.6314
# Generation: 800. 正答率(トレーニング) = 0.53
#                 : 800. 正答率(テスト) = 0.6079
# Generation: 810. 正答率(トレーニング) = 0.63
#                 : 810. 正答率(テスト) = 0.6838
# Generation: 820. 正答率(トレーニング) = 0.57
#                 : 820. 正答率(テスト) = 0.6576
# Generation: 830. 正答率(トレーニング) = 0.69
#                 : 830. 正答率(テスト) = 0.6974
# Generation: 840. 正答率(トレーニング) = 0.68
#                 : 840. 正答率(テスト) = 0.6436
# Generation: 850. 正答率(トレーニング) = 0.66
#                 : 850. 正答率(テスト) = 0.655
# Generation: 860. 正答率(トレーニング) = 0.73
#                 : 860. 正答率(テスト) = 0.6911
# Generation: 870. 正答率(トレーニング) = 0.7
#                 : 870. 正答率(テスト) = 0.7225
# Generation: 880. 正答率(トレーニング) = 0.7
#                 : 880. 正答率(テスト) = 0.6942
# Generation: 890. 正答率(トレーニング) = 0.68
#                 : 890. 正答率(テスト) = 0.6682
# Generation: 900. 正答率(トレーニング) = 0.72
#                 : 900. 正答率(テスト) = 0.7316
# Generation: 910. 正答率(トレーニング) = 0.74
#                 : 910. 正答率(テスト) = 0.7432
# Generation: 920. 正答率(トレーニング) = 0.74
#                 : 920. 正答率(テスト) = 0.7774
# Generation: 930. 正答率(トレーニング) = 0.83
#                 : 930. 正答率(テスト) = 0.7784
# Generation: 940. 正答率(トレーニング) = 0.86
#                 : 940. 正答率(テスト) = 0.794
# Generation: 950. 正答率(トレーニング) = 0.84
#                 : 950. 正答率(テスト) = 0.7799
# Generation: 960. 正答率(トレーニング) = 0.84
#                 : 960. 正答率(テスト) = 0.7989
# Generation: 970. 正答率(トレーニング) = 0.75
#                 : 970. 正答率(テスト) = 0.7887
# Generation: 980. 正答率(トレーニング) = 0.69
#                 : 980. 正答率(テスト) = 0.8012
# Generation: 990. 正答率(トレーニング) = 0.75
#                 : 990. 正答率(テスト) = 0.8145
# Generation: 1000. 正答率(トレーニング) = 0.8
#                 : 1000. 正答率(テスト) = 0.8122
# Generation: 1010. 正答率(トレーニング) = 0.78
#                 : 1010. 正答率(テスト) = 0.8081
# Generation: 1020. 正答率(トレーニング) = 0.81
#                 : 1020. 正答率(テスト) = 0.8112
# Generation: 1030. 正答率(トレーニング) = 0.73
#                 : 1030. 正答率(テスト) = 0.8284
# Generation: 1040. 正答率(トレーニング) = 0.79
#                 : 1040. 正答率(テスト) = 0.8221
# Generation: 1050. 正答率(トレーニング) = 0.84
#                 : 1050. 正答率(テスト) = 0.8181
# Generation: 1060. 正答率(トレーニング) = 0.86
#                 : 1060. 正答率(テスト) = 0.83
# Generation: 1070. 正答率(トレーニング) = 0.84
#                 : 1070. 正答率(テスト) = 0.8129
# Generation: 1080. 正答率(トレーニング) = 0.85
#                 : 1080. 正答率(テスト) = 0.8255
# Generation: 1090. 正答率(トレーニング) = 0.87
#                 : 1090. 正答率(テスト) = 0.8287
# Generation: 1100. 正答率(トレーニング) = 0.85
#                 : 1100. 正答率(テスト) = 0.8358
# Generation: 1110. 正答率(トレーニング) = 0.9
#                 : 1110. 正答率(テスト) = 0.8381
# Generation: 1120. 正答率(トレーニング) = 0.86
#                 : 1120. 正答率(テスト) = 0.8459
# Generation: 1130. 正答率(トレーニング) = 0.89
#                 : 1130. 正答率(テスト) = 0.8547
# Generation: 1140. 正答率(トレーニング) = 0.87
#                 : 1140. 正答率(テスト) = 0.8533
# Generation: 1150. 正答率(トレーニング) = 0.89
#                 : 1150. 正答率(テスト) = 0.8564
# Generation: 1160. 正答率(トレーニング) = 0.89
#                 : 1160. 正答率(テスト) = 0.8408
# Generation: 1170. 正答率(トレーニング) = 0.89
#                 : 1170. 正答率(テスト) = 0.8413
# Generation: 1180. 正答率(トレーニング) = 0.91
#                 : 1180. 正答率(テスト) = 0.8554
# Generation: 1190. 正答率(トレーニング) = 0.9
#                 : 1190. 正答率(テスト) = 0.8628
# Generation: 1200. 正答率(トレーニング) = 0.81
#                 : 1200. 正答率(テスト) = 0.8676
# Generation: 1210. 正答率(トレーニング) = 0.87
#                 : 1210. 正答率(テスト) = 0.8644
# Generation: 1220. 正答率(トレーニング) = 0.87
#                 : 1220. 正答率(テスト) = 0.8596
# Generation: 1230. 正答率(トレーニング) = 0.83
#                 : 1230. 正答率(テスト) = 0.864
# Generation: 1240. 正答率(トレーニング) = 0.84
#                 : 1240. 正答率(テスト) = 0.8748
# Generation: 1250. 正答率(トレーニング) = 0.84
#                 : 1250. 正答率(テスト) = 0.87
# Generation: 1260. 正答率(トレーニング) = 0.83
#                 : 1260. 正答率(テスト) = 0.8795
# Generation: 1270. 正答率(トレーニング) = 0.85
#                 : 1270. 正答率(テスト) = 0.8605
# Generation: 1280. 正答率(トレーニング) = 0.85
#                 : 1280. 正答率(テスト) = 0.8775
# Generation: 1290. 正答率(トレーニング) = 0.9
#                 : 1290. 正答率(テスト) = 0.8796
# Generation: 1300. 正答率(トレーニング) = 0.88
#                 : 1300. 正答率(テスト) = 0.8776
# Generation: 1310. 正答率(トレーニング) = 0.9
#                 : 1310. 正答率(テスト) = 0.8819
# Generation: 1320. 正答率(トレーニング) = 0.91
#                 : 1320. 正答率(テスト) = 0.8833
# Generation: 1330. 正答率(トレーニング) = 0.89
#                 : 1330. 正答率(テスト) = 0.8825
# Generation: 1340. 正答率(トレーニング) = 0.9
#                 : 1340. 正答率(テスト) = 0.8887
# Generation: 1350. 正答率(トレーニング) = 0.88
#                 : 1350. 正答率(テスト) = 0.8864
# Generation: 1360. 正答率(トレーニング) = 0.87
#                 : 1360. 正答率(テスト) = 0.8855
# Generation: 1370. 正答率(トレーニング) = 0.95
#                 : 1370. 正答率(テスト) = 0.8907
# Generation: 1380. 正答率(トレーニング) = 0.87
#                 : 1380. 正答率(テスト) = 0.8902
# Generation: 1390. 正答率(トレーニング) = 0.95
#                 : 1390. 正答率(テスト) = 0.8859
# Generation: 1400. 正答率(トレーニング) = 0.88
#                 : 1400. 正答率(テスト) = 0.8893
# Generation: 1410. 正答率(トレーニング) = 0.91
#                 : 1410. 正答率(テスト) = 0.8709
# Generation: 1420. 正答率(トレーニング) = 0.86
#                 : 1420. 正答率(テスト) = 0.885
# Generation: 1430. 正答率(トレーニング) = 0.95
#                 : 1430. 正答率(テスト) = 0.8908
# Generation: 1440. 正答率(トレーニング) = 0.86
#                 : 1440. 正答率(テスト) = 0.8835
# Generation: 1450. 正答率(トレーニング) = 0.9
#                 : 1450. 正答率(テスト) = 0.8822
# Generation: 1460. 正答率(トレーニング) = 0.86
#                 : 1460. 正答率(テスト) = 0.8914
# Generation: 1470. 正答率(トレーニング) = 0.91
#                 : 1470. 正答率(テスト) = 0.8946
# Generation: 1480. 正答率(トレーニング) = 0.94
#                 : 1480. 正答率(テスト) = 0.8953
# Generation: 1490. 正答率(トレーニング) = 0.88
#                 : 1490. 正答率(テスト) = 0.8988
# Generation: 1500. 正答率(トレーニング) = 0.91
#                 : 1500. 正答率(テスト) = 0.8985
# Generation: 1510. 正答率(トレーニング) = 0.85
#                 : 1510. 正答率(テスト) = 0.8895
# Generation: 1520. 正答率(トレーニング) = 0.88
#                 : 1520. 正答率(テスト) = 0.9001
# Generation: 1530. 正答率(トレーニング) = 0.81
#                 : 1530. 正答率(テスト) = 0.8962
# Generation: 1540. 正答率(トレーニング) = 0.88
#                 : 1540. 正答率(テスト) = 0.8941
# Generation: 1550. 正答率(トレーニング) = 0.91
#                 : 1550. 正答率(テスト) = 0.8928
# Generation: 1560. 正答率(トレーニング) = 0.88
#                 : 1560. 正答率(テスト) = 0.8686
# Generation: 1570. 正答率(トレーニング) = 0.91
#                 : 1570. 正答率(テスト) = 0.905
# Generation: 1580. 正答率(トレーニング) = 0.89
#                 : 1580. 正答率(テスト) = 0.8881
# Generation: 1590. 正答率(トレーニング) = 0.94
#                 : 1590. 正答率(テスト) = 0.9049
# Generation: 1600. 正答率(トレーニング) = 0.94
#                 : 1600. 正答率(テスト) = 0.8989
# Generation: 1610. 正答率(トレーニング) = 0.89
#                 : 1610. 正答率(テスト) = 0.9
# Generation: 1620. 正答率(トレーニング) = 0.94
#                 : 1620. 正答率(テスト) = 0.9038
# Generation: 1630. 正答率(トレーニング) = 0.9
#                 : 1630. 正答率(テスト) = 0.9067
# Generation: 1640. 正答率(トレーニング) = 0.89
#                 : 1640. 正答率(テスト) = 0.9063
# Generation: 1650. 正答率(トレーニング) = 0.91
#                 : 1650. 正答率(テスト) = 0.8915
# Generation: 1660. 正答率(トレーニング) = 0.93
#                 : 1660. 正答率(テスト) = 0.9023
# Generation: 1670. 正答率(トレーニング) = 0.87
#                 : 1670. 正答率(テスト) = 0.9093
# Generation: 1680. 正答率(トレーニング) = 0.87
#                 : 1680. 正答率(テスト) = 0.8857
# Generation: 1690. 正答率(トレーニング) = 0.91
#                 : 1690. 正答率(テスト) = 0.9074
# Generation: 1700. 正答率(トレーニング) = 0.9
#                 : 1700. 正答率(テスト) = 0.9127
# Generation: 1710. 正答率(トレーニング) = 0.94
#                 : 1710. 正答率(テスト) = 0.9078
# Generation: 1720. 正答率(トレーニング) = 0.89
#                 : 1720. 正答率(テスト) = 0.9064
# Generation: 1730. 正答率(トレーニング) = 0.96
#                 : 1730. 正答率(テスト) = 0.9073
# Generation: 1740. 正答率(トレーニング) = 0.91
#                 : 1740. 正答率(テスト) = 0.9087
# Generation: 1750. 正答率(トレーニング) = 0.89
#                 : 1750. 正答率(テスト) = 0.908
# Generation: 1760. 正答率(トレーニング) = 0.89
#                 : 1760. 正答率(テスト) = 0.9006
# Generation: 1770. 正答率(トレーニング) = 0.94
#                 : 1770. 正答率(テスト) = 0.9139
# Generation: 1780. 正答率(トレーニング) = 0.96
#                 : 1780. 正答率(テスト) = 0.9073
# Generation: 1790. 正答率(トレーニング) = 0.95
#                 : 1790. 正答率(テスト) = 0.9115
# Generation: 1800. 正答率(トレーニング) = 0.95
#                 : 1800. 正答率(テスト) = 0.9138
# Generation: 1810. 正答率(トレーニング) = 0.95
#                 : 1810. 正答率(テスト) = 0.9146
# Generation: 1820. 正答率(トレーニング) = 0.91
#                 : 1820. 正答率(テスト) = 0.9107
# Generation: 1830. 正答率(トレーニング) = 0.87
#                 : 1830. 正答率(テスト) = 0.9167
# Generation: 1840. 正答率(トレーニング) = 0.89
#                 : 1840. 正答率(テスト) = 0.914
# Generation: 1850. 正答率(トレーニング) = 0.93
#                 : 1850. 正答率(テスト) = 0.9167
# Generation: 1860. 正答率(トレーニング) = 0.95
#                 : 1860. 正答率(テスト) = 0.9138
# Generation: 1870. 正答率(トレーニング) = 0.93
#                 : 1870. 正答率(テスト) = 0.9082
# Generation: 1880. 正答率(トレーニング) = 0.9
#                 : 1880. 正答率(テスト) = 0.9097
# Generation: 1890. 正答率(トレーニング) = 0.88
#                 : 1890. 正答率(テスト) = 0.9137
# Generation: 1900. 正答率(トレーニング) = 0.93
#                 : 1900. 正答率(テスト) = 0.9132
# Generation: 1910. 正答率(トレーニング) = 0.9
#                 : 1910. 正答率(テスト) = 0.9179
# Generation: 1920. 正答率(トレーニング) = 0.95
#                 : 1920. 正答率(テスト) = 0.9175
# Generation: 1930. 正答率(トレーニング) = 0.92
#                 : 1930. 正答率(テスト) = 0.9202
# Generation: 1940. 正答率(トレーニング) = 0.91
#                 : 1940. 正答率(テスト) = 0.9138
# Generation: 1950. 正答率(トレーニング) = 0.89
#                 : 1950. 正答率(テスト) = 0.8989
# Generation: 1960. 正答率(トレーニング) = 0.9
#                 : 1960. 正答率(テスト) = 0.9192
# Generation: 1970. 正答率(トレーニング) = 0.94
#                 : 1970. 正答率(テスト) = 0.9218
# Generation: 1980. 正答率(トレーニング) = 0.94
#                 : 1980. 正答率(テスト) = 0.9219
# Generation: 1990. 正答率(トレーニング) = 0.92
#                 : 1990. 正答率(テスト) = 0.9225
# Generation: 2000. 正答率(トレーニング) = 0.94
#                 : 2000. 正答率(テスト) = 0.923

# %% [markdown]
# ## sigmoid - Xavier

# %%
import numpy as np
from data.mnist import load_mnist
from PIL import Image
import pickle
from common import functions
import matplotlib.pyplot as plt

# mnistをロード
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)
train_size = len(x_train)

print("データ読み込み完了")

#入力層サイズ
input_layer_size = 784
#中間層サイズ
hidden_layer_1_size = 40
hidden_layer_2_size = 20
#出力層サイズ
output_layer_size = 10
# 繰り返し数
iters_num = 2000
# ミニバッチサイズ
batch_size = 100
# 学習率
learning_rate = 0.1
# 描写頻度
plot_interval=10

# 初期設定
def init_network():
    network = {} 
    
    ###########  変更箇所  ##############
    
    # Xavierの初期値
    network['W1'] = np.random.randn(input_layer_size, hidden_layer_1_size) / (np.sqrt(input_layer_size))
    network['W2'] = np.random.randn(hidden_layer_1_size, hidden_layer_2_size) / (np.sqrt(hidden_layer_1_size))
    network['W3'] = np.random.randn(hidden_layer_2_size, output_layer_size) / (np.sqrt(hidden_layer_2_size))
    
    #################################
    
    network['b1'] = np.zeros(hidden_layer_1_size)
    network['b2'] = np.zeros(hidden_layer_2_size)
    network['b3'] = np.zeros(output_layer_size)

    return network

# 順伝播
def forward(network, x):
    W1, W2, W3 = network['W1'], network['W2'], network['W3']
    b1, b2, b3 = network['b1'], network['b2'], network['b3']
    hidden_f = functions.sigmoid
    
    u1 =  np.dot(x, W1) + b1
    z1 = hidden_f(u1)
    u2 =  np.dot(z1, W2) + b2
    z2 = hidden_f(u2)
    u3 =  np.dot(z2, W3) + b3
    y = functions.softmax(u3)
 
    return z1, z2, y

# 誤差逆伝播
def backward(x, d, z1, z2, y):
    grad = {}
    
    W1, W2, W3 = network['W1'], network['W2'], network['W3']
    b1, b2, b3 = network['b1'], network['b2'], network['b3']
    hidden_d_f = functions.d_sigmoid
    
    # 出力層でのデルタ
    delta3 = functions.d_softmax_with_loss(d, y)
    # b3の勾配
    grad['b3'] = np.sum(delta3, axis=0)
    # W3の勾配
    grad['W3'] = np.dot(z2.T, delta3)
    # 2層でのデルタ
    delta2 = np.dot(delta3, W3.T) * hidden_d_f(z2)
    # b2の勾配
    grad['b2'] = np.sum(delta2, axis=0)
    # W2の勾配
    grad['W2'] = np.dot(z1.T, delta2)
    # 1層でのデルタ
    delta1 = np.dot(delta2, W2.T) * hidden_d_f(z1)
    # b1の勾配
    grad['b1'] = np.sum(delta1, axis=0)
    # W1の勾配
    grad['W1'] = np.dot(x.T, delta1)

    return grad

# パラメータの初期化
network = init_network()

accuracies_train = []
accuracies_test = []

# 正答率
def accuracy(x, d):
    z1, z2, y = forward(network, x)
    y = np.argmax(y, axis=1)
    if d.ndim != 1 : d = np.argmax(d, axis=1)
    accuracy = np.sum(y == d) / float(x.shape[0])
    return accuracy

for i in range(iters_num):
    # ランダムにバッチを取得    
    batch_mask = np.random.choice(train_size, batch_size)
    # ミニバッチに対応する教師訓練画像データを取得    
    x_batch = x_train[batch_mask]
    # ミニバッチに対応する訓練正解ラベルデータを取得する
    d_batch = d_train[batch_mask]


    
    z1, z2, y = forward(network, x_batch)
    grad = backward(x_batch, d_batch, z1, z2, y)

    if (i+1)%plot_interval==0:
        accr_test = accuracy(x_test, d_test)
        accuracies_test.append(accr_test)
        
        accr_train = accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)

        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
        
    # パラメータに勾配適用
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network[key]  -= learning_rate * grad[key]


lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.07
#                 : 10. 正答率(テスト) = 0.0974
# Generation: 20. 正答率(トレーニング) = 0.08
#                 : 20. 正答率(テスト) = 0.1172
# Generation: 30. 正答率(トレーニング) = 0.11
#                 : 30. 正答率(テスト) = 0.1291
# Generation: 40. 正答率(トレーニング) = 0.07
#                 : 40. 正答率(テスト) = 0.1099
# Generation: 50. 正答率(トレーニング) = 0.08
#                 : 50. 正答率(テスト) = 0.1427
# Generation: 60. 正答率(トレーニング) = 0.15
#                 : 60. 正答率(テスト) = 0.1402
# Generation: 70. 正答率(トレーニング) = 0.1
#                 : 70. 正答率(テスト) = 0.1369
# Generation: 80. 正答率(トレーニング) = 0.17
#                 : 80. 正答率(テスト) = 0.117
# Generation: 90. 正答率(トレーニング) = 0.23
#                 : 90. 正答率(テスト) = 0.3088
# Generation: 100. 正答率(トレーニング) = 0.31
#                 : 100. 正答率(テスト) = 0.2873
# Generation: 110. 正答率(トレーニング) = 0.09
#                 : 110. 正答率(テスト) = 0.1032
# Generation: 120. 正答率(トレーニング) = 0.28
#                 : 120. 正答率(テスト) = 0.3034
# Generation: 130. 正答率(トレーニング) = 0.1
#                 : 130. 正答率(テスト) = 0.1034
# Generation: 140. 正答率(トレーニング) = 0.32
#                 : 140. 正答率(テスト) = 0.3722
# Generation: 150. 正答率(トレーニング) = 0.27
#                 : 150. 正答率(テスト) = 0.3089
# Generation: 160. 正答率(トレーニング) = 0.34
#                 : 160. 正答率(テスト) = 0.3683
# Generation: 170. 正答率(トレーニング) = 0.27
#                 : 170. 正答率(テスト) = 0.394
# Generation: 180. 正答率(トレーニング) = 0.4
#                 : 180. 正答率(テスト) = 0.3771
# Generation: 190. 正答率(トレーニング) = 0.33
#                 : 190. 正答率(テスト) = 0.2434
# Generation: 200. 正答率(トレーニング) = 0.46
#                 : 200. 正答率(テスト) = 0.4179
# Generation: 210. 正答率(トレーニング) = 0.43
#                 : 210. 正答率(テスト) = 0.4844
# Generation: 220. 正答率(トレーニング) = 0.32
#                 : 220. 正答率(テスト) = 0.4308
# Generation: 230. 正答率(トレーニング) = 0.52
#                 : 230. 正答率(テスト) = 0.4528
# Generation: 240. 正答率(トレーニング) = 0.48
#                 : 240. 正答率(テスト) = 0.4246
# Generation: 250. 正答率(トレーニング) = 0.39
#                 : 250. 正答率(テスト) = 0.4506
# Generation: 260. 正答率(トレーニング) = 0.54
#                 : 260. 正答率(テスト) = 0.5776
# Generation: 270. 正答率(トレーニング) = 0.57
#                 : 270. 正答率(テスト) = 0.5836
# Generation: 280. 正答率(トレーニング) = 0.41
#                 : 280. 正答率(テスト) = 0.4412
# Generation: 290. 正答率(トレーニング) = 0.55
#                 : 290. 正答率(テスト) = 0.5197
# Generation: 300. 正答率(トレーニング) = 0.5
#                 : 300. 正答率(テスト) = 0.4566
# Generation: 310. 正答率(トレーニング) = 0.47
#                 : 310. 正答率(テスト) = 0.4856
# Generation: 320. 正答率(トレーニング) = 0.5
#                 : 320. 正答率(テスト) = 0.4901
# Generation: 330. 正答率(トレーニング) = 0.36
#                 : 330. 正答率(テスト) = 0.4621
# Generation: 340. 正答率(トレーニング) = 0.58
#                 : 340. 正答率(テスト) = 0.5092
# Generation: 350. 正答率(トレーニング) = 0.51
#                 : 350. 正答率(テスト) = 0.5034
# Generation: 360. 正答率(トレーニング) = 0.49
#                 : 360. 正答率(テスト) = 0.4936
# Generation: 370. 正答率(トレーニング) = 0.49
#                 : 370. 正答率(テスト) = 0.5087
# Generation: 380. 正答率(トレーニング) = 0.44
#                 : 380. 正答率(テスト) = 0.5208
# Generation: 390. 正答率(トレーニング) = 0.52
#                 : 390. 正答率(テスト) = 0.5709
# Generation: 400. 正答率(トレーニング) = 0.63
#                 : 400. 正答率(テスト) = 0.5393
# Generation: 410. 正答率(トレーニング) = 0.52
#                 : 410. 正答率(テスト) = 0.5279
# Generation: 420. 正答率(トレーニング) = 0.53
#                 : 420. 正答率(テスト) = 0.5184
# Generation: 430. 正答率(トレーニング) = 0.45
#                 : 430. 正答率(テスト) = 0.5366
# Generation: 440. 正答率(トレーニング) = 0.52
#                 : 440. 正答率(テスト) = 0.5485
# Generation: 450. 正答率(トレーニング) = 0.54
#                 : 450. 正答率(テスト) = 0.5421
# Generation: 460. 正答率(トレーニング) = 0.59
#                 : 460. 正答率(テスト) = 0.5477
# Generation: 470. 正答率(トレーニング) = 0.53
#                 : 470. 正答率(テスト) = 0.5525
# Generation: 480. 正答率(トレーニング) = 0.57
#                 : 480. 正答率(テスト) = 0.5893
# Generation: 490. 正答率(トレーニング) = 0.62
#                 : 490. 正答率(テスト) = 0.5936
# Generation: 500. 正答率(トレーニング) = 0.51
#                 : 500. 正答率(テスト) = 0.5648
# Generation: 510. 正答率(トレーニング) = 0.71
#                 : 510. 正答率(テスト) = 0.5693
# Generation: 520. 正答率(トレーニング) = 0.64
#                 : 520. 正答率(テスト) = 0.5639
# Generation: 530. 正答率(トレーニング) = 0.52
#                 : 530. 正答率(テスト) = 0.5483
# Generation: 540. 正答率(トレーニング) = 0.47
#                 : 540. 正答率(テスト) = 0.5673
# Generation: 550. 正答率(トレーニング) = 0.66
#                 : 550. 正答率(テスト) = 0.5774
# Generation: 560. 正答率(トレーニング) = 0.56
#                 : 560. 正答率(テスト) = 0.5592
# Generation: 570. 正答率(トレーニング) = 0.61
#                 : 570. 正答率(テスト) = 0.5726
# Generation: 580. 正答率(トレーニング) = 0.62
#                 : 580. 正答率(テスト) = 0.5984
# Generation: 590. 正答率(トレーニング) = 0.63
#                 : 590. 正答率(テスト) = 0.6051
# Generation: 600. 正答率(トレーニング) = 0.57
#                 : 600. 正答率(テスト) = 0.605
# Generation: 610. 正答率(トレーニング) = 0.58
#                 : 610. 正答率(テスト) = 0.6053
# Generation: 620. 正答率(トレーニング) = 0.63
#                 : 620. 正答率(テスト) = 0.604
# Generation: 630. 正答率(トレーニング) = 0.54
#                 : 630. 正答率(テスト) = 0.6084
# Generation: 640. 正答率(トレーニング) = 0.61
#                 : 640. 正答率(テスト) = 0.6285
# Generation: 650. 正答率(トレーニング) = 0.63
#                 : 650. 正答率(テスト) = 0.6204
# Generation: 660. 正答率(トレーニング) = 0.73
#                 : 660. 正答率(テスト) = 0.6231
# Generation: 670. 正答率(トレーニング) = 0.63
#                 : 670. 正答率(テスト) = 0.6145
# Generation: 680. 正答率(トレーニング) = 0.72
#                 : 680. 正答率(テスト) = 0.6207
# Generation: 690. 正答率(トレーニング) = 0.63
#                 : 690. 正答率(テスト) = 0.6315
# Generation: 700. 正答率(トレーニング) = 0.62
#                 : 700. 正答率(テスト) = 0.6418
# Generation: 710. 正答率(トレーニング) = 0.65
#                 : 710. 正答率(テスト) = 0.6398
# Generation: 720. 正答率(トレーニング) = 0.62
#                 : 720. 正答率(テスト) = 0.6268
# Generation: 730. 正答率(トレーニング) = 0.61
#                 : 730. 正答率(テスト) = 0.6404
# Generation: 740. 正答率(トレーニング) = 0.56
#                 : 740. 正答率(テスト) = 0.6483
# Generation: 750. 正答率(トレーニング) = 0.64
#                 : 750. 正答率(テスト) = 0.6604
# Generation: 760. 正答率(トレーニング) = 0.68
#                 : 760. 正答率(テスト) = 0.6627
# Generation: 770. 正答率(トレーニング) = 0.57
#                 : 770. 正答率(テスト) = 0.6565
# Generation: 780. 正答率(トレーニング) = 0.61
#                 : 780. 正答率(テスト) = 0.6667
# Generation: 790. 正答率(トレーニング) = 0.68
#                 : 790. 正答率(テスト) = 0.6626
# Generation: 800. 正答率(トレーニング) = 0.63
#                 : 800. 正答率(テスト) = 0.6686
# Generation: 810. 正答率(トレーニング) = 0.64
#                 : 810. 正答率(テスト) = 0.6736
# Generation: 820. 正答率(トレーニング) = 0.76
#                 : 820. 正答率(テスト) = 0.6784
# Generation: 830. 正答率(トレーニング) = 0.64
#                 : 830. 正答率(テスト) = 0.6815
# Generation: 840. 正答率(トレーニング) = 0.72
#                 : 840. 正答率(テスト) = 0.6821
# Generation: 850. 正答率(トレーニング) = 0.67
#                 : 850. 正答率(テスト) = 0.6766
# Generation: 860. 正答率(トレーニング) = 0.67
#                 : 860. 正答率(テスト) = 0.6847
# Generation: 870. 正答率(トレーニング) = 0.62
#                 : 870. 正答率(テスト) = 0.6866
# Generation: 880. 正答率(トレーニング) = 0.69
#                 : 880. 正答率(テスト) = 0.6865
# Generation: 890. 正答率(トレーニング) = 0.74
#                 : 890. 正答率(テスト) = 0.6858
# Generation: 900. 正答率(トレーニング) = 0.8
#                 : 900. 正答率(テスト) = 0.6888
# Generation: 910. 正答率(トレーニング) = 0.62
#                 : 910. 正答率(テスト) = 0.6898
# Generation: 920. 正答率(トレーニング) = 0.71
#                 : 920. 正答率(テスト) = 0.6967
# Generation: 930. 正答率(トレーニング) = 0.65
#                 : 930. 正答率(テスト) = 0.6985
# Generation: 940. 正答率(トレーニング) = 0.68
#                 : 940. 正答率(テスト) = 0.6976
# Generation: 950. 正答率(トレーニング) = 0.75
#                 : 950. 正答率(テスト) = 0.704
# Generation: 960. 正答率(トレーニング) = 0.72
#                 : 960. 正答率(テスト) = 0.7102
# Generation: 970. 正答率(トレーニング) = 0.74
#                 : 970. 正答率(テスト) = 0.7119
# Generation: 980. 正答率(トレーニング) = 0.69
#                 : 980. 正答率(テスト) = 0.7087
# Generation: 990. 正答率(トレーニング) = 0.67
#                 : 990. 正答率(テスト) = 0.7084
# Generation: 1000. 正答率(トレーニング) = 0.66
#                 : 1000. 正答率(テスト) = 0.7183
# Generation: 1010. 正答率(トレーニング) = 0.76
#                 : 1010. 正答率(テスト) = 0.7239
# Generation: 1020. 正答率(トレーニング) = 0.79
#                 : 1020. 正答率(テスト) = 0.7306
# Generation: 1030. 正答率(トレーニング) = 0.7
#                 : 1030. 正答率(テスト) = 0.7284
# Generation: 1040. 正答率(トレーニング) = 0.74
#                 : 1040. 正答率(テスト) = 0.7264
# Generation: 1050. 正答率(トレーニング) = 0.75
#                 : 1050. 正答率(テスト) = 0.7288
# Generation: 1060. 正答率(トレーニング) = 0.67
#                 : 1060. 正答率(テスト) = 0.7206
# Generation: 1070. 正答率(トレーニング) = 0.71
#                 : 1070. 正答率(テスト) = 0.7296
# Generation: 1080. 正答率(トレーニング) = 0.75
#                 : 1080. 正答率(テスト) = 0.7413
# Generation: 1090. 正答率(トレーニング) = 0.75
#                 : 1090. 正答率(テスト) = 0.7332
# Generation: 1100. 正答率(トレーニング) = 0.79
#                 : 1100. 正答率(テスト) = 0.745
# Generation: 1110. 正答率(トレーニング) = 0.67
#                 : 1110. 正答率(テスト) = 0.7436
# Generation: 1120. 正答率(トレーニング) = 0.75
#                 : 1120. 正答率(テスト) = 0.7465
# Generation: 1130. 正答率(トレーニング) = 0.77
#                 : 1130. 正答率(テスト) = 0.7575
# Generation: 1140. 正答率(トレーニング) = 0.82
#                 : 1140. 正答率(テスト) = 0.756
# Generation: 1150. 正答率(トレーニング) = 0.76
#                 : 1150. 正答率(テスト) = 0.7529
# Generation: 1160. 正答率(トレーニング) = 0.72
#                 : 1160. 正答率(テスト) = 0.7571
# Generation: 1170. 正答率(トレーニング) = 0.77
#                 : 1170. 正答率(テスト) = 0.7614
# Generation: 1180. 正答率(トレーニング) = 0.77
#                 : 1180. 正答率(テスト) = 0.7662
# Generation: 1190. 正答率(トレーニング) = 0.75
#                 : 1190. 正答率(テスト) = 0.7667
# Generation: 1200. 正答率(トレーニング) = 0.72
#                 : 1200. 正答率(テスト) = 0.7646
# Generation: 1210. 正答率(トレーニング) = 0.8
#                 : 1210. 正答率(テスト) = 0.7714
# Generation: 1220. 正答率(トレーニング) = 0.79
#                 : 1220. 正答率(テスト) = 0.7666
# Generation: 1230. 正答率(トレーニング) = 0.86
#                 : 1230. 正答率(テスト) = 0.7716
# Generation: 1240. 正答率(トレーニング) = 0.68
#                 : 1240. 正答率(テスト) = 0.7774
# Generation: 1250. 正答率(トレーニング) = 0.81
#                 : 1250. 正答率(テスト) = 0.7793
# Generation: 1260. 正答率(トレーニング) = 0.69
#                 : 1260. 正答率(テスト) = 0.7768
# Generation: 1270. 正答率(トレーニング) = 0.79
#                 : 1270. 正答率(テスト) = 0.7796
# Generation: 1280. 正答率(トレーニング) = 0.76
#                 : 1280. 正答率(テスト) = 0.7793
# Generation: 1290. 正答率(トレーニング) = 0.68
#                 : 1290. 正答率(テスト) = 0.7807
# Generation: 1300. 正答率(トレーニング) = 0.79
#                 : 1300. 正答率(テスト) = 0.7859
# Generation: 1310. 正答率(トレーニング) = 0.7
#                 : 1310. 正答率(テスト) = 0.7835
# Generation: 1320. 正答率(トレーニング) = 0.78
#                 : 1320. 正答率(テスト) = 0.7859
# Generation: 1330. 正答率(トレーニング) = 0.79
#                 : 1330. 正答率(テスト) = 0.7855
# Generation: 1340. 正答率(トレーニング) = 0.75
#                 : 1340. 正答率(テスト) = 0.7865
# Generation: 1350. 正答率(トレーニング) = 0.73
#                 : 1350. 正答率(テスト) = 0.7882
# Generation: 1360. 正答率(トレーニング) = 0.77
#                 : 1360. 正答率(テスト) = 0.7868
# Generation: 1370. 正答率(トレーニング) = 0.73
#                 : 1370. 正答率(テスト) = 0.7875
# Generation: 1380. 正答率(トレーニング) = 0.79
#                 : 1380. 正答率(テスト) = 0.7921
# Generation: 1390. 正答率(トレーニング) = 0.76
#                 : 1390. 正答率(テスト) = 0.7906
# Generation: 1400. 正答率(トレーニング) = 0.85
#                 : 1400. 正答率(テスト) = 0.7885
# Generation: 1410. 正答率(トレーニング) = 0.74
#                 : 1410. 正答率(テスト) = 0.7914
# Generation: 1420. 正答率(トレーニング) = 0.75
#                 : 1420. 正答率(テスト) = 0.7976
# Generation: 1430. 正答率(トレーニング) = 0.83
#                 : 1430. 正答率(テスト) = 0.7942
# Generation: 1440. 正答率(トレーニング) = 0.75
#                 : 1440. 正答率(テスト) = 0.7967
# Generation: 1450. 正答率(トレーニング) = 0.8
#                 : 1450. 正答率(テスト) = 0.799
# Generation: 1460. 正答率(トレーニング) = 0.84
#                 : 1460. 正答率(テスト) = 0.8004
# Generation: 1470. 正答率(トレーニング) = 0.82
#                 : 1470. 正答率(テスト) = 0.8011
# Generation: 1480. 正答率(トレーニング) = 0.74
#                 : 1480. 正答率(テスト) = 0.8031
# Generation: 1490. 正答率(トレーニング) = 0.84
#                 : 1490. 正答率(テスト) = 0.803
# Generation: 1500. 正答率(トレーニング) = 0.87
#                 : 1500. 正答率(テスト) = 0.8022
# Generation: 1510. 正答率(トレーニング) = 0.75
#                 : 1510. 正答率(テスト) = 0.803
# Generation: 1520. 正答率(トレーニング) = 0.72
#                 : 1520. 正答率(テスト) = 0.8035
# Generation: 1530. 正答率(トレーニング) = 0.78
#                 : 1530. 正答率(テスト) = 0.8065
# Generation: 1540. 正答率(トレーニング) = 0.85
#                 : 1540. 正答率(テスト) = 0.8053
# Generation: 1550. 正答率(トレーニング) = 0.84
#                 : 1550. 正答率(テスト) = 0.8047
# Generation: 1560. 正答率(トレーニング) = 0.84
#                 : 1560. 正答率(テスト) = 0.8059
# Generation: 1570. 正答率(トレーニング) = 0.81
#                 : 1570. 正答率(テスト) = 0.8089
# Generation: 1580. 正答率(トレーニング) = 0.86
#                 : 1580. 正答率(テスト) = 0.8101
# Generation: 1590. 正答率(トレーニング) = 0.8
#                 : 1590. 正答率(テスト) = 0.8124
# Generation: 1600. 正答率(トレーニング) = 0.85
#                 : 1600. 正答率(テスト) = 0.8103
# Generation: 1610. 正答率(トレーニング) = 0.81
#                 : 1610. 正答率(テスト) = 0.8115
# Generation: 1620. 正答率(トレーニング) = 0.8
#                 : 1620. 正答率(テスト) = 0.8117
# Generation: 1630. 正答率(トレーニング) = 0.76
#                 : 1630. 正答率(テスト) = 0.8131
# Generation: 1640. 正答率(トレーニング) = 0.85
#                 : 1640. 正答率(テスト) = 0.8149
# Generation: 1650. 正答率(トレーニング) = 0.72
#                 : 1650. 正答率(テスト) = 0.8147
# Generation: 1660. 正答率(トレーニング) = 0.79
#                 : 1660. 正答率(テスト) = 0.8144
# Generation: 1670. 正答率(トレーニング) = 0.74
#                 : 1670. 正答率(テスト) = 0.817
# Generation: 1680. 正答率(トレーニング) = 0.8
#                 : 1680. 正答率(テスト) = 0.8164
# Generation: 1690. 正答率(トレーニング) = 0.79
#                 : 1690. 正答率(テスト) = 0.8176
# Generation: 1700. 正答率(トレーニング) = 0.77
#                 : 1700. 正答率(テスト) = 0.8176
# Generation: 1710. 正答率(トレーニング) = 0.85
#                 : 1710. 正答率(テスト) = 0.818
# Generation: 1720. 正答率(トレーニング) = 0.79
#                 : 1720. 正答率(テスト) = 0.8182
# Generation: 1730. 正答率(トレーニング) = 0.87
#                 : 1730. 正答率(テスト) = 0.8208
# Generation: 1740. 正答率(トレーニング) = 0.83
#                 : 1740. 正答率(テスト) = 0.8208
# Generation: 1750. 正答率(トレーニング) = 0.83
#                 : 1750. 正答率(テスト) = 0.8212
# Generation: 1760. 正答率(トレーニング) = 0.77
#                 : 1760. 正答率(テスト) = 0.8216
# Generation: 1770. 正答率(トレーニング) = 0.78
#                 : 1770. 正答率(テスト) = 0.8218
# Generation: 1780. 正答率(トレーニング) = 0.87
#                 : 1780. 正答率(テスト) = 0.8214
# Generation: 1790. 正答率(トレーニング) = 0.82
#                 : 1790. 正答率(テスト) = 0.8219
# Generation: 1800. 正答率(トレーニング) = 0.88
#                 : 1800. 正答率(テスト) = 0.8222
# Generation: 1810. 正答率(トレーニング) = 0.78
#                 : 1810. 正答率(テスト) = 0.8224
# Generation: 1820. 正答率(トレーニング) = 0.69
#                 : 1820. 正答率(テスト) = 0.8232
# Generation: 1830. 正答率(トレーニング) = 0.83
#                 : 1830. 正答率(テスト) = 0.8238
# Generation: 1840. 正答率(トレーニング) = 0.85
#                 : 1840. 正答率(テスト) = 0.8239
# Generation: 1850. 正答率(トレーニング) = 0.84
#                 : 1850. 正答率(テスト) = 0.8247
# Generation: 1860. 正答率(トレーニング) = 0.75
#                 : 1860. 正答率(テスト) = 0.8261
# Generation: 1870. 正答率(トレーニング) = 0.86
#                 : 1870. 正答率(テスト) = 0.8275
# Generation: 1880. 正答率(トレーニング) = 0.87
#                 : 1880. 正答率(テスト) = 0.8253
# Generation: 1890. 正答率(トレーニング) = 0.83
#                 : 1890. 正答率(テスト) = 0.8264
# Generation: 1900. 正答率(トレーニング) = 0.77
#                 : 1900. 正答率(テスト) = 0.8258
# Generation: 1910. 正答率(トレーニング) = 0.86
#                 : 1910. 正答率(テスト) = 0.8275
# Generation: 1920. 正答率(トレーニング) = 0.83
#                 : 1920. 正答率(テスト) = 0.8269
# Generation: 1930. 正答率(トレーニング) = 0.78
#                 : 1930. 正答率(テスト) = 0.8276
# Generation: 1940. 正答率(トレーニング) = 0.8
#                 : 1940. 正答率(テスト) = 0.8283
# Generation: 1950. 正答率(トレーニング) = 0.86
#                 : 1950. 正答率(テスト) = 0.8298
# Generation: 1960. 正答率(トレーニング) = 0.74
#                 : 1960. 正答率(テスト) = 0.8308
# Generation: 1970. 正答率(トレーニング) = 0.73
#                 : 1970. 正答率(テスト) = 0.8315
# Generation: 1980. 正答率(トレーニング) = 0.82
#                 : 1980. 正答率(テスト) = 0.8291
# Generation: 1990. 正答率(トレーニング) = 0.87
#                 : 1990. 正答率(テスト) = 0.8311
# Generation: 2000. 正答率(トレーニング) = 0.75
#                 : 2000. 正答率(テスト) = 0.8332

# %% [markdown]
# ## ReLU - He

# %%
import numpy as np
from data.mnist import load_mnist
from PIL import Image
import pickle
from common import functions
import matplotlib.pyplot as plt

# mnistをロード
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)
train_size = len(x_train)

print("データ読み込み完了")

# 重み初期値補正係数
wieght_init = 0.01
#入力層サイズ
input_layer_size = 784
#中間層サイズ
hidden_layer_1_size = 40
hidden_layer_2_size = 20

#出力層サイズ
output_layer_size = 10
# 繰り返し数
iters_num = 2000
# ミニバッチサイズ
batch_size = 100
# 学習率
learning_rate = 0.1
# 描写頻度
plot_interval=10

# 初期設定
def init_network():
    network = {} 

    ###########  変更箇所  ##############

    # Heの初期値
    network['W1'] = np.random.randn(input_layer_size, hidden_layer_1_size) / np.sqrt(input_layer_size) * np.sqrt(2)
    network['W2'] = np.random.randn(hidden_layer_1_size, hidden_layer_2_size) / np.sqrt(hidden_layer_1_size) * np.sqrt(2)
    network['W3'] = np.random.randn(hidden_layer_2_size, output_layer_size) / np.sqrt(hidden_layer_2_size) * np.sqrt(2)
        
    #################################
    
    network['b1'] = np.zeros(hidden_layer_1_size)
    network['b2'] = np.zeros(hidden_layer_2_size)
    network['b3'] = np.zeros(output_layer_size)

    return network

# 順伝播
def forward(network, x):
    W1, W2, W3 = network['W1'], network['W2'], network['W3']
    b1, b2, b3 = network['b1'], network['b2'], network['b3']

    ###########  変更箇所  ##############
    
    hidden_f = functions.relu
    
    #################################
    
    u1 =  np.dot(x, W1) + b1
    z1 = hidden_f(u1)
    u2 =  np.dot(z1, W2) + b2
    z2 = hidden_f(u2)
    u3 =  np.dot(z2, W3) + b3
    y = functions.softmax(u3)
 
    return z1, z2, y

# 誤差逆伝播
def backward(x, d, z1, z2, y):
    grad = {}
    
    W1, W2, W3 = network['W1'], network['W2'], network['W3']
    b1, b2, b3 = network['b1'], network['b2'], network['b3']
    
    ###########  変更箇所  ##############
    
    hidden_d_f = functions.d_relu
    
    #################################
    
    # 出力層でのデルタ
    delta3 = functions.d_softmax_with_loss(d, y)
    # b3の勾配
    grad['b3'] = np.sum(delta3, axis=0)
    # W3の勾配
    grad['W3'] = np.dot(z2.T, delta3)
    # 2層でのデルタ
    delta2 = np.dot(delta3, W3.T) * hidden_d_f(z2)
    # b2の勾配
    grad['b2'] = np.sum(delta2, axis=0)
    # W2の勾配
    grad['W2'] = np.dot(z1.T, delta2)
    # 1層でのデルタ
    delta1 = np.dot(delta2, W2.T) * hidden_d_f(z1)
    # b1の勾配
    grad['b1'] = np.sum(delta1, axis=0)
    # W1の勾配
    grad['W1'] = np.dot(x.T, delta1)

    return grad

# パラメータの初期化
network = init_network()

accuracies_train = []
accuracies_test = []

# 正答率
def accuracy(x, d):
    z1, z2, y = forward(network, x)
    y = np.argmax(y, axis=1)
    if d.ndim != 1 : d = np.argmax(d, axis=1)
    accuracy = np.sum(y == d) / float(x.shape[0])
    return accuracy

for i in range(iters_num):
    # ランダムにバッチを取得    
    batch_mask = np.random.choice(train_size, batch_size)
    # ミニバッチに対応する教師訓練画像データを取得    
    x_batch = x_train[batch_mask]
    # ミニバッチに対応する訓練正解ラベルデータを取得する
    d_batch = d_train[batch_mask]


    
    z1, z2, y = forward(network, x_batch)
    grad = backward(x_batch, d_batch, z1, z2, y)

    if (i+1)%plot_interval==0:
        accr_test = accuracy(x_test, d_test)
        accuracies_test.append(accr_test)
        
        accr_train = accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)

        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
        
    # パラメータに勾配適用
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network[key]  -= learning_rate * grad[key]


lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.31
#                 : 10. 正答率(テスト) = 0.3352
# Generation: 20. 正答率(トレーニング) = 0.63
#                 : 20. 正答率(テスト) = 0.5797
# Generation: 30. 正答率(トレーニング) = 0.65
#                 : 30. 正答率(テスト) = 0.7207
# Generation: 40. 正答率(トレーニング) = 0.78
#                 : 40. 正答率(テスト) = 0.7727
# Generation: 50. 正答率(トレーニング) = 0.84
#                 : 50. 正答率(テスト) = 0.7841
# Generation: 60. 正答率(トレーニング) = 0.87
#                 : 60. 正答率(テスト) = 0.8497
# Generation: 70. 正答率(トレーニング) = 0.87
#                 : 70. 正答率(テスト) = 0.8252
# Generation: 80. 正答率(トレーニング) = 0.88
#                 : 80. 正答率(テスト) = 0.854
# Generation: 90. 正答率(トレーニング) = 0.89
#                 : 90. 正答率(テスト) = 0.8618
# Generation: 100. 正答率(トレーニング) = 0.9
#                 : 100. 正答率(テスト) = 0.8723
# Generation: 110. 正答率(トレーニング) = 0.84
#                 : 110. 正答率(テスト) = 0.8766
# Generation: 120. 正答率(トレーニング) = 0.82
#                 : 120. 正答率(テスト) = 0.8491
# Generation: 130. 正答率(トレーニング) = 0.88
#                 : 130. 正答率(テスト) = 0.8784
# Generation: 140. 正答率(トレーニング) = 0.92
#                 : 140. 正答率(テスト) = 0.8816
# Generation: 150. 正答率(トレーニング) = 0.9
#                 : 150. 正答率(テスト) = 0.884
# Generation: 160. 正答率(トレーニング) = 0.91
#                 : 160. 正答率(テスト) = 0.899
# Generation: 170. 正答率(トレーニング) = 0.95
#                 : 170. 正答率(テスト) = 0.8985
# Generation: 180. 正答率(トレーニング) = 0.87
#                 : 180. 正答率(テスト) = 0.8946
# Generation: 190. 正答率(トレーニング) = 0.93
#                 : 190. 正答率(テスト) = 0.8919
# Generation: 200. 正答率(トレーニング) = 0.9
#                 : 200. 正答率(テスト) = 0.8995
# Generation: 210. 正答率(トレーニング) = 0.94
#                 : 210. 正答率(テスト) = 0.8991
# Generation: 220. 正答率(トレーニング) = 0.93
#                 : 220. 正答率(テスト) = 0.9036
# Generation: 230. 正答率(トレーニング) = 0.92
#                 : 230. 正答率(テスト) = 0.9103
# Generation: 240. 正答率(トレーニング) = 0.87
#                 : 240. 正答率(テスト) = 0.9092
# Generation: 250. 正答率(トレーニング) = 0.85
#                 : 250. 正答率(テスト) = 0.9118
# Generation: 260. 正答率(トレーニング) = 0.89
#                 : 260. 正答率(テスト) = 0.9046
# Generation: 270. 正答率(トレーニング) = 0.87
#                 : 270. 正答率(テスト) = 0.9056
# Generation: 280. 正答率(トレーニング) = 0.9
#                 : 280. 正答率(テスト) = 0.9092
# Generation: 290. 正答率(トレーニング) = 0.9
#                 : 290. 正答率(テスト) = 0.9037
# Generation: 300. 正答率(トレーニング) = 0.87
#                 : 300. 正答率(テスト) = 0.9075
# Generation: 310. 正答率(トレーニング) = 0.91
#                 : 310. 正答率(テスト) = 0.9165
# Generation: 320. 正答率(トレーニング) = 0.83
#                 : 320. 正答率(テスト) = 0.8895
# Generation: 330. 正答率(トレーニング) = 0.95
#                 : 330. 正答率(テスト) = 0.917
# Generation: 340. 正答率(トレーニング) = 0.9
#                 : 340. 正答率(テスト) = 0.9173
# Generation: 350. 正答率(トレーニング) = 0.91
#                 : 350. 正答率(テスト) = 0.919
# Generation: 360. 正答率(トレーニング) = 0.91
#                 : 360. 正答率(テスト) = 0.9196
# Generation: 370. 正答率(トレーニング) = 0.91
#                 : 370. 正答率(テスト) = 0.924
# Generation: 380. 正答率(トレーニング) = 0.91
#                 : 380. 正答率(テスト) = 0.9112
# Generation: 390. 正答率(トレーニング) = 0.93
#                 : 390. 正答率(テスト) = 0.911
# Generation: 400. 正答率(トレーニング) = 0.91
#                 : 400. 正答率(テスト) = 0.9138
# Generation: 410. 正答率(トレーニング) = 0.9
#                 : 410. 正答率(テスト) = 0.9157
# Generation: 420. 正答率(トレーニング) = 0.88
#                 : 420. 正答率(テスト) = 0.9093
# Generation: 430. 正答率(トレーニング) = 0.97
#                 : 430. 正答率(テスト) = 0.9173
# Generation: 440. 正答率(トレーニング) = 0.92
#                 : 440. 正答率(テスト) = 0.923
# Generation: 450. 正答率(トレーニング) = 0.96
#                 : 450. 正答率(テスト) = 0.9212
# Generation: 460. 正答率(トレーニング) = 0.9
#                 : 460. 正答率(テスト) = 0.9232
# Generation: 470. 正答率(トレーニング) = 0.93
#                 : 470. 正答率(テスト) = 0.9206
# Generation: 480. 正答率(トレーニング) = 0.93
#                 : 480. 正答率(テスト) = 0.9259
# Generation: 490. 正答率(トレーニング) = 0.93
#                 : 490. 正答率(テスト) = 0.9279
# Generation: 500. 正答率(トレーニング) = 0.91
#                 : 500. 正答率(テスト) = 0.9283
# Generation: 510. 正答率(トレーニング) = 0.97
#                 : 510. 正答率(テスト) = 0.9307
# Generation: 520. 正答率(トレーニング) = 0.93
#                 : 520. 正答率(テスト) = 0.9319
# Generation: 530. 正答率(トレーニング) = 0.96
#                 : 530. 正答率(テスト) = 0.9298
# Generation: 540. 正答率(トレーニング) = 0.92
#                 : 540. 正答率(テスト) = 0.9358
# Generation: 550. 正答率(トレーニング) = 0.95
#                 : 550. 正答率(テスト) = 0.9339
# Generation: 560. 正答率(トレーニング) = 0.89
#                 : 560. 正答率(テスト) = 0.933
# Generation: 570. 正答率(トレーニング) = 0.94
#                 : 570. 正答率(テスト) = 0.9247
# Generation: 580. 正答率(トレーニング) = 0.92
#                 : 580. 正答率(テスト) = 0.9342
# Generation: 590. 正答率(トレーニング) = 0.96
#                 : 590. 正答率(テスト) = 0.9245
# Generation: 600. 正答率(トレーニング) = 0.9
#                 : 600. 正答率(テスト) = 0.9349
# Generation: 610. 正答率(トレーニング) = 0.9
#                 : 610. 正答率(テスト) = 0.9328
# Generation: 620. 正答率(トレーニング) = 0.86
#                 : 620. 正答率(テスト) = 0.9335
# Generation: 630. 正答率(トレーニング) = 0.94
#                 : 630. 正答率(テスト) = 0.9338
# Generation: 640. 正答率(トレーニング) = 0.94
#                 : 640. 正答率(テスト) = 0.9337
# Generation: 650. 正答率(トレーニング) = 0.92
#                 : 650. 正答率(テスト) = 0.9313
# Generation: 660. 正答率(トレーニング) = 0.95
#                 : 660. 正答率(テスト) = 0.933
# Generation: 670. 正答率(トレーニング) = 0.96
#                 : 670. 正答率(テスト) = 0.9342
# Generation: 680. 正答率(トレーニング) = 0.97
#                 : 680. 正答率(テスト) = 0.9287
# Generation: 690. 正答率(トレーニング) = 0.94
#                 : 690. 正答率(テスト) = 0.9336
# Generation: 700. 正答率(トレーニング) = 0.89
#                 : 700. 正答率(テスト) = 0.9356
# Generation: 710. 正答率(トレーニング) = 0.92
#                 : 710. 正答率(テスト) = 0.9383
# Generation: 720. 正答率(トレーニング) = 0.95
#                 : 720. 正答率(テスト) = 0.935
# Generation: 730. 正答率(トレーニング) = 0.92
#                 : 730. 正答率(テスト) = 0.934
# Generation: 740. 正答率(トレーニング) = 0.91
#                 : 740. 正答率(テスト) = 0.9356
# Generation: 750. 正答率(トレーニング) = 0.91
#                 : 750. 正答率(テスト) = 0.9325
# Generation: 760. 正答率(トレーニング) = 0.92
#                 : 760. 正答率(テスト) = 0.9247
# Generation: 770. 正答率(トレーニング) = 0.93
#                 : 770. 正答率(テスト) = 0.9352
# Generation: 780. 正答率(トレーニング) = 0.94
#                 : 780. 正答率(テスト) = 0.9351
# Generation: 790. 正答率(トレーニング) = 0.96
#                 : 790. 正答率(テスト) = 0.9341
# Generation: 800. 正答率(トレーニング) = 0.93
#                 : 800. 正答率(テスト) = 0.9386
# Generation: 810. 正答率(トレーニング) = 0.9
#                 : 810. 正答率(テスト) = 0.9335
# Generation: 820. 正答率(トレーニング) = 0.9
#                 : 820. 正答率(テスト) = 0.9362
# Generation: 830. 正答率(トレーニング) = 0.92
#                 : 830. 正答率(テスト) = 0.9313
# Generation: 840. 正答率(トレーニング) = 0.95
#                 : 840. 正答率(テスト) = 0.9378
# Generation: 850. 正答率(トレーニング) = 0.94
#                 : 850. 正答率(テスト) = 0.9343
# Generation: 860. 正答率(トレーニング) = 0.94
#                 : 860. 正答率(テスト) = 0.9343
# Generation: 870. 正答率(トレーニング) = 0.97
#                 : 870. 正答率(テスト) = 0.9377
# Generation: 880. 正答率(トレーニング) = 0.95
#                 : 880. 正答率(テスト) = 0.9421
# Generation: 890. 正答率(トレーニング) = 0.89
#                 : 890. 正答率(テスト) = 0.9371
# Generation: 900. 正答率(トレーニング) = 0.95
#                 : 900. 正答率(テスト) = 0.9364
# Generation: 910. 正答率(トレーニング) = 0.95
#                 : 910. 正答率(テスト) = 0.936
# Generation: 920. 正答率(トレーニング) = 0.96
#                 : 920. 正答率(テスト) = 0.9332
# Generation: 930. 正答率(トレーニング) = 0.94
#                 : 930. 正答率(テスト) = 0.9248
# Generation: 940. 正答率(トレーニング) = 0.94
#                 : 940. 正答率(テスト) = 0.9402
# Generation: 950. 正答率(トレーニング) = 0.96
#                 : 950. 正答率(テスト) = 0.9449
# Generation: 960. 正答率(トレーニング) = 0.98
#                 : 960. 正答率(テスト) = 0.9415
# Generation: 970. 正答率(トレーニング) = 0.94
#                 : 970. 正答率(テスト) = 0.9422
# Generation: 980. 正答率(トレーニング) = 0.95
#                 : 980. 正答率(テスト) = 0.9404
# Generation: 990. 正答率(トレーニング) = 0.96
#                 : 990. 正答率(テスト) = 0.9435
# Generation: 1000. 正答率(トレーニング) = 0.94
#                 : 1000. 正答率(テスト) = 0.9365
# Generation: 1010. 正答率(トレーニング) = 0.98
#                 : 1010. 正答率(テスト) = 0.9424
# Generation: 1020. 正答率(トレーニング) = 0.91
#                 : 1020. 正答率(テスト) = 0.9384
# Generation: 1030. 正答率(トレーニング) = 0.94
#                 : 1030. 正答率(テスト) = 0.9423
# Generation: 1040. 正答率(トレーニング) = 0.96
#                 : 1040. 正答率(テスト) = 0.9403
# Generation: 1050. 正答率(トレーニング) = 0.92
#                 : 1050. 正答率(テスト) = 0.9443
# Generation: 1060. 正答率(トレーニング) = 0.95
#                 : 1060. 正答率(テスト) = 0.9431
# Generation: 1070. 正答率(トレーニング) = 0.95
#                 : 1070. 正答率(テスト) = 0.9434
# Generation: 1080. 正答率(トレーニング) = 0.97
#                 : 1080. 正答率(テスト) = 0.9413
# Generation: 1090. 正答率(トレーニング) = 0.94
#                 : 1090. 正答率(テスト) = 0.9431
# Generation: 1100. 正答率(トレーニング) = 0.95
#                 : 1100. 正答率(テスト) = 0.9328
# Generation: 1110. 正答率(トレーニング) = 0.93
#                 : 1110. 正答率(テスト) = 0.9451
# Generation: 1120. 正答率(トレーニング) = 0.95
#                 : 1120. 正答率(テスト) = 0.9473
# Generation: 1130. 正答率(トレーニング) = 0.95
#                 : 1130. 正答率(テスト) = 0.9446
# Generation: 1140. 正答率(トレーニング) = 0.96
#                 : 1140. 正答率(テスト) = 0.9404
# Generation: 1150. 正答率(トレーニング) = 0.94
#                 : 1150. 正答率(テスト) = 0.9436
# Generation: 1160. 正答率(トレーニング) = 0.96
#                 : 1160. 正答率(テスト) = 0.9421
# Generation: 1170. 正答率(トレーニング) = 0.95
#                 : 1170. 正答率(テスト) = 0.9442
# Generation: 1180. 正答率(トレーニング) = 0.93
#                 : 1180. 正答率(テスト) = 0.9451
# Generation: 1190. 正答率(トレーニング) = 0.94
#                 : 1190. 正答率(テスト) = 0.9419
# Generation: 1200. 正答率(トレーニング) = 0.95
#                 : 1200. 正答率(テスト) = 0.9459
# Generation: 1210. 正答率(トレーニング) = 0.94
#                 : 1210. 正答率(テスト) = 0.9394
# Generation: 1220. 正答率(トレーニング) = 0.94
#                 : 1220. 正答率(テスト) = 0.9492
# Generation: 1230. 正答率(トレーニング) = 0.95
#                 : 1230. 正答率(テスト) = 0.9424
# Generation: 1240. 正答率(トレーニング) = 0.93
#                 : 1240. 正答率(テスト) = 0.9414
# Generation: 1250. 正答率(トレーニング) = 0.96
#                 : 1250. 正答率(テスト) = 0.9467
# Generation: 1260. 正答率(トレーニング) = 0.97
#                 : 1260. 正答率(テスト) = 0.947
# Generation: 1270. 正答率(トレーニング) = 0.96
#                 : 1270. 正答率(テスト) = 0.9467
# Generation: 1280. 正答率(トレーニング) = 0.92
#                 : 1280. 正答率(テスト) = 0.9452
# Generation: 1290. 正答率(トレーニング) = 0.94
#                 : 1290. 正答率(テスト) = 0.9352
# Generation: 1300. 正答率(トレーニング) = 0.95
#                 : 1300. 正答率(テスト) = 0.9453
# Generation: 1310. 正答率(トレーニング) = 0.94
#                 : 1310. 正答率(テスト) = 0.9467
# Generation: 1320. 正答率(トレーニング) = 0.97
#                 : 1320. 正答率(テスト) = 0.945
# Generation: 1330. 正答率(トレーニング) = 0.91
#                 : 1330. 正答率(テスト) = 0.9461
# Generation: 1340. 正答率(トレーニング) = 0.96
#                 : 1340. 正答率(テスト) = 0.9483
# Generation: 1350. 正答率(トレーニング) = 0.94
#                 : 1350. 正答率(テスト) = 0.9487
# Generation: 1360. 正答率(トレーニング) = 0.94
#                 : 1360. 正答率(テスト) = 0.9501
# Generation: 1370. 正答率(トレーニング) = 0.92
#                 : 1370. 正答率(テスト) = 0.9489
# Generation: 1380. 正答率(トレーニング) = 0.98
#                 : 1380. 正答率(テスト) = 0.9457
# Generation: 1390. 正答率(トレーニング) = 0.96
#                 : 1390. 正答率(テスト) = 0.9494
# Generation: 1400. 正答率(トレーニング) = 0.97
#                 : 1400. 正答率(テスト) = 0.9506
# Generation: 1410. 正答率(トレーニング) = 0.94
#                 : 1410. 正答率(テスト) = 0.9405
# Generation: 1420. 正答率(トレーニング) = 0.94
#                 : 1420. 正答率(テスト) = 0.9483
# Generation: 1430. 正答率(トレーニング) = 0.94
#                 : 1430. 正答率(テスト) = 0.9455
# Generation: 1440. 正答率(トレーニング) = 0.98
#                 : 1440. 正答率(テスト) = 0.9479
# Generation: 1450. 正答率(トレーニング) = 0.94
#                 : 1450. 正答率(テスト) = 0.9499
# Generation: 1460. 正答率(トレーニング) = 1.0
#                 : 1460. 正答率(テスト) = 0.9494
# Generation: 1470. 正答率(トレーニング) = 0.95
#                 : 1470. 正答率(テスト) = 0.9465
# Generation: 1480. 正答率(トレーニング) = 0.96
#                 : 1480. 正答率(テスト) = 0.946
# Generation: 1490. 正答率(トレーニング) = 0.94
#                 : 1490. 正答率(テスト) = 0.9448
# Generation: 1500. 正答率(トレーニング) = 0.99
#                 : 1500. 正答率(テスト) = 0.95
# Generation: 1510. 正答率(トレーニング) = 0.91
#                 : 1510. 正答率(テスト) = 0.9489
# Generation: 1520. 正答率(トレーニング) = 0.97
#                 : 1520. 正答率(テスト) = 0.9489
# Generation: 1530. 正答率(トレーニング) = 0.96
#                 : 1530. 正答率(テスト) = 0.9454
# Generation: 1540. 正答率(トレーニング) = 0.95
#                 : 1540. 正答率(テスト) = 0.9497
# Generation: 1550. 正答率(トレーニング) = 0.99
#                 : 1550. 正答率(テスト) = 0.9496
# Generation: 1560. 正答率(トレーニング) = 0.98
#                 : 1560. 正答率(テスト) = 0.9509
# Generation: 1570. 正答率(トレーニング) = 0.97
#                 : 1570. 正答率(テスト) = 0.9472
# Generation: 1580. 正答率(トレーニング) = 0.97
#                 : 1580. 正答率(テスト) = 0.9519
# Generation: 1590. 正答率(トレーニング) = 0.95
#                 : 1590. 正答率(テスト) = 0.9495
# Generation: 1600. 正答率(トレーニング) = 0.93
#                 : 1600. 正答率(テスト) = 0.9511
# Generation: 1610. 正答率(トレーニング) = 0.93
#                 : 1610. 正答率(テスト) = 0.95
# Generation: 1620. 正答率(トレーニング) = 0.97
#                 : 1620. 正答率(テスト) = 0.9537
# Generation: 1630. 正答率(トレーニング) = 0.97
#                 : 1630. 正答率(テスト) = 0.9474
# Generation: 1640. 正答率(トレーニング) = 0.93
#                 : 1640. 正答率(テスト) = 0.9518
# Generation: 1650. 正答率(トレーニング) = 0.95
#                 : 1650. 正答率(テスト) = 0.9479
# Generation: 1660. 正答率(トレーニング) = 0.92
#                 : 1660. 正答率(テスト) = 0.9443
# Generation: 1670. 正答率(トレーニング) = 0.96
#                 : 1670. 正答率(テスト) = 0.953
# Generation: 1680. 正答率(トレーニング) = 0.97
#                 : 1680. 正答率(テスト) = 0.954
# Generation: 1690. 正答率(トレーニング) = 0.97
#                 : 1690. 正答率(テスト) = 0.951
# Generation: 1700. 正答率(トレーニング) = 0.94
#                 : 1700. 正答率(テスト) = 0.9483
# Generation: 1710. 正答率(トレーニング) = 0.93
#                 : 1710. 正答率(テスト) = 0.9512
# Generation: 1720. 正答率(トレーニング) = 0.95
#                 : 1720. 正答率(テスト) = 0.953
# Generation: 1730. 正答率(トレーニング) = 0.9
#                 : 1730. 正答率(テスト) = 0.951
# Generation: 1740. 正答率(トレーニング) = 0.99
#                 : 1740. 正答率(テスト) = 0.953
# Generation: 1750. 正答率(トレーニング) = 0.96
#                 : 1750. 正答率(テスト) = 0.9538
# Generation: 1760. 正答率(トレーニング) = 0.96
#                 : 1760. 正答率(テスト) = 0.9476
# Generation: 1770. 正答率(トレーニング) = 0.94
#                 : 1770. 正答率(テスト) = 0.951
# Generation: 1780. 正答率(トレーニング) = 0.95
#                 : 1780. 正答率(テスト) = 0.949
# Generation: 1790. 正答率(トレーニング) = 0.98
#                 : 1790. 正答率(テスト) = 0.9526
# Generation: 1800. 正答率(トレーニング) = 0.93
#                 : 1800. 正答率(テスト) = 0.9507
# Generation: 1810. 正答率(トレーニング) = 0.96
#                 : 1810. 正答率(テスト) = 0.9474
# Generation: 1820. 正答率(トレーニング) = 0.98
#                 : 1820. 正答率(テスト) = 0.9494
# Generation: 1830. 正答率(トレーニング) = 0.97
#                 : 1830. 正答率(テスト) = 0.945
# Generation: 1840. 正答率(トレーニング) = 0.95
#                 : 1840. 正答率(テスト) = 0.952
# Generation: 1850. 正答率(トレーニング) = 0.95
#                 : 1850. 正答率(テスト) = 0.9441
# Generation: 1860. 正答率(トレーニング) = 0.97
#                 : 1860. 正答率(テスト) = 0.9518
# Generation: 1870. 正答率(トレーニング) = 0.96
#                 : 1870. 正答率(テスト) = 0.9519
# Generation: 1880. 正答率(トレーニング) = 0.92
#                 : 1880. 正答率(テスト) = 0.9545
# Generation: 1890. 正答率(トレーニング) = 0.94
#                 : 1890. 正答率(テスト) = 0.9529
# Generation: 1900. 正答率(トレーニング) = 0.98
#                 : 1900. 正答率(テスト) = 0.9522
# Generation: 1910. 正答率(トレーニング) = 0.97
#                 : 1910. 正答率(テスト) = 0.9515
# Generation: 1920. 正答率(トレーニング) = 0.97
#                 : 1920. 正答率(テスト) = 0.953
# Generation: 1930. 正答率(トレーニング) = 0.95
#                 : 1930. 正答率(テスト) = 0.943
# Generation: 1940. 正答率(トレーニング) = 0.94
#                 : 1940. 正答率(テスト) = 0.952
# Generation: 1950. 正答率(トレーニング) = 0.95
#                 : 1950. 正答率(テスト) = 0.9544
# Generation: 1960. 正答率(トレーニング) = 0.96
#                 : 1960. 正答率(テスト) = 0.9523
# Generation: 1970. 正答率(トレーニング) = 0.95
#                 : 1970. 正答率(テスト) = 0.9535
# Generation: 1980. 正答率(トレーニング) = 0.96
#                 : 1980. 正答率(テスト) = 0.9497
# Generation: 1990. 正答率(トレーニング) = 0.93
#                 : 1990. 正答率(テスト) = 0.9539
# Generation: 2000. 正答率(トレーニング) = 0.93
#                 : 2000. 正答率(テスト) = 0.9511
