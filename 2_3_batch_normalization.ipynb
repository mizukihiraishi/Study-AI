# %% [markdown]
# # 準備

# %% [markdown]
# ## Googleドライブのマウント

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## sys.pathの設定

# %% [markdown]
# 以下では，Googleドライブのマイドライブ直下にDNN_codeフォルダを置くことを仮定しています．必要に応じて，パスを変更してください．

# %%
import sys
sys.path.append('/content/drive/My Drive/DNN_code')
sys.path.append('/content/drive/My Drive/DNN_code/lesson_2')

# %% [markdown]
# # batch normalization

# %%
import numpy as np
from collections import OrderedDict
from common import layers
from data.mnist import load_mnist
import matplotlib.pyplot as plt
from multi_layer_net import MultiLayerNet
from common import optimizer

# バッチ正則化 layer
class BatchNormalization:
    '''
    gamma: スケール係数
    beta: オフセット
    momentum: 慣性
    running_mean: テスト時に使用する平均
    running_var: テスト時に使用する分散
    '''
    def __init__(self, gamma, beta, momentum=0.9, running_mean=None, running_var=None):
        self.gamma = gamma
        self.beta = beta
        self.momentum = momentum
        self.input_shape = None

        self.running_mean = running_mean
        self.running_var = running_var  
        
        # backward時に使用する中間データ
        self.batch_size = None
        self.xc = None
        self.std = None
        self.dgamma = None
        self.dbeta = None

    def forward(self, x, train_flg=True):
        if self.running_mean is None:
            N, D = x.shape
            self.running_mean = np.zeros(D)
            self.running_var = np.zeros(D)
                        
        if train_flg:
            mu = x.mean(axis=0) # 平均
            xc = x - mu # xをセンタリング
            var = np.mean(xc**2, axis=0) # 分散
            std = np.sqrt(var + 10e-7) # スケーリング
            xn = xc / std
            
            self.batch_size = x.shape[0]
            self.xc = xc
            self.xn = xn
            self.std = std
            self.running_mean = self.momentum * self.running_mean + (1-self.momentum) * mu # 平均値の加重平均
            self.running_var = self.momentum * self.running_var + (1-self.momentum) * var #分散値の加重平均
        else:
            xc = x - self.running_mean
            xn = xc / ((np.sqrt(self.running_var + 10e-7)))
            
        out = self.gamma * xn + self.beta 
        
        return out

    def backward(self, dout):
        dbeta = dout.sum(axis=0)
        dgamma = np.sum(self.xn * dout, axis=0)
        dxn = self.gamma * dout
        dxc = dxn / self.std
        dstd = -np.sum((dxn * self.xc) / (self.std * self.std), axis=0)
        dvar = 0.5 * dstd / self.std
        dxc += (2.0 / self.batch_size) * self.xc * dvar
        dmu = np.sum(dxc, axis=0)
        dx = dxc - dmu / self.batch_size
        
        self.dgamma = dgamma
        self.dbeta = dbeta

        return dx

# %%
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True)

print("データ読み込み完了")


# batch_normalizationの設定 =======================
use_batchnorm = True
# use_batchnorm = False
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10,
                        activation='sigmoid', weight_init_std='Xavier', use_batchnorm=use_batchnorm)

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100
learning_rate=0.01

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10


for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    grad = network.gradient(x_batch, d_batch)
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network.params[key] -= learning_rate * grad[key]

        loss = network.loss(x_batch, d_batch)
        train_loss_list.append(loss)        
        
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
                

lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.12
#                 : 10. 正答率(テスト) = 0.1085
# Generation: 20. 正答率(トレーニング) = 0.14
#                 : 20. 正答率(テスト) = 0.1301
# Generation: 30. 正答率(トレーニング) = 0.14
#                 : 30. 正答率(テスト) = 0.1559
# Generation: 40. 正答率(トレーニング) = 0.15
#                 : 40. 正答率(テスト) = 0.1798
# Generation: 50. 正答率(トレーニング) = 0.2
#                 : 50. 正答率(テスト) = 0.2111
# Generation: 60. 正答率(トレーニング) = 0.27
#                 : 60. 正答率(テスト) = 0.2478
# Generation: 70. 正答率(トレーニング) = 0.3
#                 : 70. 正答率(テスト) = 0.2743
# Generation: 80. 正答率(トレーニング) = 0.28
#                 : 80. 正答率(テスト) = 0.3066
# Generation: 90. 正答率(トレーニング) = 0.41
#                 : 90. 正答率(テスト) = 0.3602
# Generation: 100. 正答率(トレーニング) = 0.46
#                 : 100. 正答率(テスト) = 0.4023
# Generation: 110. 正答率(トレーニング) = 0.41
#                 : 110. 正答率(テスト) = 0.4473
# Generation: 120. 正答率(トレーニング) = 0.41
#                 : 120. 正答率(テスト) = 0.4755
# Generation: 130. 正答率(トレーニング) = 0.5
#                 : 130. 正答率(テスト) = 0.4989
# Generation: 140. 正答率(トレーニング) = 0.58
#                 : 140. 正答率(テスト) = 0.5151
# Generation: 150. 正答率(トレーニング) = 0.5
#                 : 150. 正答率(テスト) = 0.5272
# Generation: 160. 正答率(トレーニング) = 0.49
#                 : 160. 正答率(テスト) = 0.5476
# Generation: 170. 正答率(トレーニング) = 0.59
#                 : 170. 正答率(テスト) = 0.5603
# Generation: 180. 正答率(トレーニング) = 0.52
#                 : 180. 正答率(テスト) = 0.5692
# Generation: 190. 正答率(トレーニング) = 0.55
#                 : 190. 正答率(テスト) = 0.5823
# Generation: 200. 正答率(トレーニング) = 0.59
#                 : 200. 正答率(テスト) = 0.5893
# Generation: 210. 正答率(トレーニング) = 0.63
#                 : 210. 正答率(テスト) = 0.6003
# Generation: 220. 正答率(トレーニング) = 0.7
#                 : 220. 正答率(テスト) = 0.6111
# Generation: 230. 正答率(トレーニング) = 0.62
#                 : 230. 正答率(テスト) = 0.6131
# Generation: 240. 正答率(トレーニング) = 0.61
#                 : 240. 正答率(テスト) = 0.6242
# Generation: 250. 正答率(トレーニング) = 0.65
#                 : 250. 正答率(テスト) = 0.6316
# Generation: 260. 正答率(トレーニング) = 0.63
#                 : 260. 正答率(テスト) = 0.6398
# Generation: 270. 正答率(トレーニング) = 0.7
#                 : 270. 正答率(テスト) = 0.6421
# Generation: 280. 正答率(トレーニング) = 0.62
#                 : 280. 正答率(テスト) = 0.6446
# Generation: 290. 正答率(トレーニング) = 0.68
#                 : 290. 正答率(テスト) = 0.6472
# Generation: 300. 正答率(トレーニング) = 0.63
#                 : 300. 正答率(テスト) = 0.654
# Generation: 310. 正答率(トレーニング) = 0.71
#                 : 310. 正答率(テスト) = 0.6639
# Generation: 320. 正答率(トレーニング) = 0.65
#                 : 320. 正答率(テスト) = 0.6737
# Generation: 330. 正答率(トレーニング) = 0.66
#                 : 330. 正答率(テスト) = 0.676
# Generation: 340. 正答率(トレーニング) = 0.65
#                 : 340. 正答率(テスト) = 0.6733
# Generation: 350. 正答率(トレーニング) = 0.67
#                 : 350. 正答率(テスト) = 0.6828
# Generation: 360. 正答率(トレーニング) = 0.68
#                 : 360. 正答率(テスト) = 0.6865
# Generation: 370. 正答率(トレーニング) = 0.7
#                 : 370. 正答率(テスト) = 0.6917
# Generation: 380. 正答率(トレーニング) = 0.69
#                 : 380. 正答率(テスト) = 0.6962
# Generation: 390. 正答率(トレーニング) = 0.67
#                 : 390. 正答率(テスト) = 0.696
# Generation: 400. 正答率(トレーニング) = 0.67
#                 : 400. 正答率(テスト) = 0.6959
# Generation: 410. 正答率(トレーニング) = 0.77
#                 : 410. 正答率(テスト) = 0.6992
# Generation: 420. 正答率(トレーニング) = 0.73
#                 : 420. 正答率(テスト) = 0.7071
# Generation: 430. 正答率(トレーニング) = 0.69
#                 : 430. 正答率(テスト) = 0.7087
# Generation: 440. 正答率(トレーニング) = 0.69
#                 : 440. 正答率(テスト) = 0.7082
# Generation: 450. 正答率(トレーニング) = 0.78
#                 : 450. 正答率(テスト) = 0.7117
# Generation: 460. 正答率(トレーニング) = 0.77
#                 : 460. 正答率(テスト) = 0.7137
# Generation: 470. 正答率(トレーニング) = 0.78
#                 : 470. 正答率(テスト) = 0.7173
# Generation: 480. 正答率(トレーニング) = 0.72
#                 : 480. 正答率(テスト) = 0.7201
# Generation: 490. 正答率(トレーニング) = 0.76
#                 : 490. 正答率(テスト) = 0.7216
# Generation: 500. 正答率(トレーニング) = 0.7
#                 : 500. 正答率(テスト) = 0.7229
# Generation: 510. 正答率(トレーニング) = 0.69
#                 : 510. 正答率(テスト) = 0.7223
# Generation: 520. 正答率(トレーニング) = 0.71
#                 : 520. 正答率(テスト) = 0.7282
# Generation: 530. 正答率(トレーニング) = 0.74
#                 : 530. 正答率(テスト) = 0.7245
# Generation: 540. 正答率(トレーニング) = 0.77
#                 : 540. 正答率(テスト) = 0.7289
# Generation: 550. 正答率(トレーニング) = 0.76
#                 : 550. 正答率(テスト) = 0.7268
# Generation: 560. 正答率(トレーニング) = 0.7
#                 : 560. 正答率(テスト) = 0.7279
# Generation: 570. 正答率(トレーニング) = 0.78
#                 : 570. 正答率(テスト) = 0.7315
# Generation: 580. 正答率(トレーニング) = 0.68
#                 : 580. 正答率(テスト) = 0.7291
# Generation: 590. 正答率(トレーニング) = 0.71
#                 : 590. 正答率(テスト) = 0.7341
# Generation: 600. 正答率(トレーニング) = 0.68
#                 : 600. 正答率(テスト) = 0.7341
# Generation: 610. 正答率(トレーニング) = 0.72
#                 : 610. 正答率(テスト) = 0.7344
# Generation: 620. 正答率(トレーニング) = 0.67
#                 : 620. 正答率(テスト) = 0.7342
# Generation: 630. 正答率(トレーニング) = 0.73
#                 : 630. 正答率(テスト) = 0.7385
# Generation: 640. 正答率(トレーニング) = 0.74
#                 : 640. 正答率(テスト) = 0.7378
# Generation: 650. 正答率(トレーニング) = 0.82
#                 : 650. 正答率(テスト) = 0.7378
# Generation: 660. 正答率(トレーニング) = 0.61
#                 : 660. 正答率(テスト) = 0.7393
# Generation: 670. 正答率(トレーニング) = 0.71
#                 : 670. 正答率(テスト) = 0.7414
# Generation: 680. 正答率(トレーニング) = 0.74
#                 : 680. 正答率(テスト) = 0.7418
# Generation: 690. 正答率(トレーニング) = 0.71
#                 : 690. 正答率(テスト) = 0.7417
# Generation: 700. 正答率(トレーニング) = 0.76
#                 : 700. 正答率(テスト) = 0.7473
# Generation: 710. 正答率(トレーニング) = 0.73
#                 : 710. 正答率(テスト) = 0.7416
# Generation: 720. 正答率(トレーニング) = 0.73
#                 : 720. 正答率(テスト) = 0.7443
# Generation: 730. 正答率(トレーニング) = 0.82
#                 : 730. 正答率(テスト) = 0.7439
# Generation: 740. 正答率(トレーニング) = 0.77
#                 : 740. 正答率(テスト) = 0.7504
# Generation: 750. 正答率(トレーニング) = 0.8
#                 : 750. 正答率(テスト) = 0.7536
# Generation: 760. 正答率(トレーニング) = 0.76
#                 : 760. 正答率(テスト) = 0.758
# Generation: 770. 正答率(トレーニング) = 0.76
#                 : 770. 正答率(テスト) = 0.7589
# Generation: 780. 正答率(トレーニング) = 0.7
#                 : 780. 正答率(テスト) = 0.7579
# Generation: 790. 正答率(トレーニング) = 0.81
#                 : 790. 正答率(テスト) = 0.7612
# Generation: 800. 正答率(トレーニング) = 0.77
#                 : 800. 正答率(テスト) = 0.7597
# Generation: 810. 正答率(トレーニング) = 0.82
#                 : 810. 正答率(テスト) = 0.7606
# Generation: 820. 正答率(トレーニング) = 0.76
#                 : 820. 正答率(テスト) = 0.7615
# Generation: 830. 正答率(トレーニング) = 0.76
#                 : 830. 正答率(テスト) = 0.7641
# Generation: 840. 正答率(トレーニング) = 0.72
#                 : 840. 正答率(テスト) = 0.7632
# Generation: 850. 正答率(トレーニング) = 0.77
#                 : 850. 正答率(テスト) = 0.7664
# Generation: 860. 正答率(トレーニング) = 0.74
#                 : 860. 正答率(テスト) = 0.7666
# Generation: 870. 正答率(トレーニング) = 0.84
#                 : 870. 正答率(テスト) = 0.7682
# Generation: 880. 正答率(トレーニング) = 0.86
#                 : 880. 正答率(テスト) = 0.7686
# Generation: 890. 正答率(トレーニング) = 0.7
#                 : 890. 正答率(テスト) = 0.7709
# Generation: 900. 正答率(トレーニング) = 0.79
#                 : 900. 正答率(テスト) = 0.7768
# Generation: 910. 正答率(トレーニング) = 0.81
#                 : 910. 正答率(テスト) = 0.7767
# Generation: 920. 正答率(トレーニング) = 0.75
#                 : 920. 正答率(テスト) = 0.7792
# Generation: 930. 正答率(トレーニング) = 0.77
#                 : 930. 正答率(テスト) = 0.7776
# Generation: 940. 正答率(トレーニング) = 0.74
#                 : 940. 正答率(テスト) = 0.78
# Generation: 950. 正答率(トレーニング) = 0.81
#                 : 950. 正答率(テスト) = 0.7809
# Generation: 960. 正答率(トレーニング) = 0.82
#                 : 960. 正答率(テスト) = 0.7783
# Generation: 970. 正答率(トレーニング) = 0.86
#                 : 970. 正答率(テスト) = 0.7769
# Generation: 980. 正答率(トレーニング) = 0.84
#                 : 980. 正答率(テスト) = 0.7778
# Generation: 990. 正答率(トレーニング) = 0.89
#                 : 990. 正答率(テスト) = 0.7751
# Generation: 1000. 正答率(トレーニング) = 0.81
#                 : 1000. 正答率(テスト) = 0.7777

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ## [try] 活性化関数や重みの初期値を変えてみよう
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True)

print("データ読み込み完了")


# batch_normalizationの設定 =======================
use_batchnorm = True
# use_batchnorm = False
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10,
                        activation='relu', weight_init_std='He', use_batchnorm=use_batchnorm)

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100
learning_rate=0.01

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10


for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    grad = network.gradient(x_batch, d_batch)
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network.params[key] -= learning_rate * grad[key]

        loss = network.loss(x_batch, d_batch)
        train_loss_list.append(loss)        
        
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
                

lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 10. 正答率(トレーニング) = 0.24
#                 : 10. 正答率(テスト) = 0.1923
# Generation: 20. 正答率(トレーニング) = 0.25
#                 : 20. 正答率(テスト) = 0.3408
# Generation: 30. 正答率(トレーニング) = 0.34
#                 : 30. 正答率(テスト) = 0.4119
# Generation: 40. 正答率(トレーニング) = 0.54
#                 : 40. 正答率(テスト) = 0.4578
# Generation: 50. 正答率(トレーニング) = 0.57
#                 : 50. 正答率(テスト) = 0.4983
# Generation: 60. 正答率(トレーニング) = 0.49
#                 : 60. 正答率(テスト) = 0.5275
# Generation: 70. 正答率(トレーニング) = 0.53
#                 : 70. 正答率(テスト) = 0.5586
# Generation: 80. 正答率(トレーニング) = 0.55
#                 : 80. 正答率(テスト) = 0.5941
# Generation: 90. 正答率(トレーニング) = 0.61
#                 : 90. 正答率(テスト) = 0.6137
# Generation: 100. 正答率(トレーニング) = 0.68
#                 : 100. 正答率(テスト) = 0.6389
# Generation: 110. 正答率(トレーニング) = 0.59
#                 : 110. 正答率(テスト) = 0.6595
# Generation: 120. 正答率(トレーニング) = 0.71
#                 : 120. 正答率(テスト) = 0.675
# Generation: 130. 正答率(トレーニング) = 0.72
#                 : 130. 正答率(テスト) = 0.6874
# Generation: 140. 正答率(トレーニング) = 0.68
#                 : 140. 正答率(テスト) = 0.7066
# Generation: 150. 正答率(トレーニング) = 0.74
#                 : 150. 正答率(テスト) = 0.7173
# Generation: 160. 正答率(トレーニング) = 0.69
#                 : 160. 正答率(テスト) = 0.73
# Generation: 170. 正答率(トレーニング) = 0.69
#                 : 170. 正答率(テスト) = 0.7429
# Generation: 180. 正答率(トレーニング) = 0.77
#                 : 180. 正答率(テスト) = 0.7553
# Generation: 190. 正答率(トレーニング) = 0.73
#                 : 190. 正答率(テスト) = 0.7668
# Generation: 200. 正答率(トレーニング) = 0.79
#                 : 200. 正答率(テスト) = 0.7713
# Generation: 210. 正答率(トレーニング) = 0.78
#                 : 210. 正答率(テスト) = 0.7825
# Generation: 220. 正答率(トレーニング) = 0.81
#                 : 220. 正答率(テスト) = 0.7882
# Generation: 230. 正答率(トレーニング) = 0.8
#                 : 230. 正答率(テスト) = 0.7912
# Generation: 240. 正答率(トレーニング) = 0.8
#                 : 240. 正答率(テスト) = 0.799
# Generation: 250. 正答率(トレーニング) = 0.81
#                 : 250. 正答率(テスト) = 0.802
# Generation: 260. 正答率(トレーニング) = 0.82
#                 : 260. 正答率(テスト) = 0.8103
# Generation: 270. 正答率(トレーニング) = 0.83
#                 : 270. 正答率(テスト) = 0.813
# Generation: 280. 正答率(トレーニング) = 0.91
#                 : 280. 正答率(テスト) = 0.817
# Generation: 290. 正答率(トレーニング) = 0.84
#                 : 290. 正答率(テスト) = 0.8192
# Generation: 300. 正答率(トレーニング) = 0.82
#                 : 300. 正答率(テスト) = 0.8247
# Generation: 310. 正答率(トレーニング) = 0.81
#                 : 310. 正答率(テスト) = 0.8291
# Generation: 320. 正答率(トレーニング) = 0.81
#                 : 320. 正答率(テスト) = 0.8322
# Generation: 330. 正答率(トレーニング) = 0.84
#                 : 330. 正答率(テスト) = 0.8364
# Generation: 340. 正答率(トレーニング) = 0.86
#                 : 340. 正答率(テスト) = 0.8363
# Generation: 350. 正答率(トレーニング) = 0.84
#                 : 350. 正答率(テスト) = 0.8403
# Generation: 360. 正答率(トレーニング) = 0.78
#                 : 360. 正答率(テスト) = 0.8404
# Generation: 370. 正答率(トレーニング) = 0.79
#                 : 370. 正答率(テスト) = 0.8437
# Generation: 380. 正答率(トレーニング) = 0.87
#                 : 380. 正答率(テスト) = 0.8447
# Generation: 390. 正答率(トレーニング) = 0.91
#                 : 390. 正答率(テスト) = 0.8449
# Generation: 400. 正答率(トレーニング) = 0.75
#                 : 400. 正答率(テスト) = 0.8496
# Generation: 410. 正答率(トレーニング) = 0.84
#                 : 410. 正答率(テスト) = 0.8518
# Generation: 420. 正答率(トレーニング) = 0.87
#                 : 420. 正答率(テスト) = 0.8529
# Generation: 430. 正答率(トレーニング) = 0.8
#                 : 430. 正答率(テスト) = 0.854
# Generation: 440. 正答率(トレーニング) = 0.91
#                 : 440. 正答率(テスト) = 0.8535
# Generation: 450. 正答率(トレーニング) = 0.9
#                 : 450. 正答率(テスト) = 0.8569
# Generation: 460. 正答率(トレーニング) = 0.8
#                 : 460. 正答率(テスト) = 0.8579
# Generation: 470. 正答率(トレーニング) = 0.79
#                 : 470. 正答率(テスト) = 0.8586
# Generation: 480. 正答率(トレーニング) = 0.85
#                 : 480. 正答率(テスト) = 0.8603
# Generation: 490. 正答率(トレーニング) = 0.83
#                 : 490. 正答率(テスト) = 0.8617
# Generation: 500. 正答率(トレーニング) = 0.88
#                 : 500. 正答率(テスト) = 0.8662
# Generation: 510. 正答率(トレーニング) = 0.85
#                 : 510. 正答率(テスト) = 0.866
# Generation: 520. 正答率(トレーニング) = 0.81
#                 : 520. 正答率(テスト) = 0.8687
# Generation: 530. 正答率(トレーニング) = 0.83
#                 : 530. 正答率(テスト) = 0.8728
# Generation: 540. 正答率(トレーニング) = 0.87
#                 : 540. 正答率(テスト) = 0.872
# Generation: 550. 正答率(トレーニング) = 0.86
#                 : 550. 正答率(テスト) = 0.8724
# Generation: 560. 正答率(トレーニング) = 0.84
#                 : 560. 正答率(テスト) = 0.8731
# Generation: 570. 正答率(トレーニング) = 0.87
#                 : 570. 正答率(テスト) = 0.8749
# Generation: 580. 正答率(トレーニング) = 0.91
#                 : 580. 正答率(テスト) = 0.8735
# Generation: 590. 正答率(トレーニング) = 0.93
#                 : 590. 正答率(テスト) = 0.8756
# Generation: 600. 正答率(トレーニング) = 0.87
#                 : 600. 正答率(テスト) = 0.8769
# Generation: 610. 正答率(トレーニング) = 0.91
#                 : 610. 正答率(テスト) = 0.8782
# Generation: 620. 正答率(トレーニング) = 0.85
#                 : 620. 正答率(テスト) = 0.8804
# Generation: 630. 正答率(トレーニング) = 0.86
#                 : 630. 正答率(テスト) = 0.881
# Generation: 640. 正答率(トレーニング) = 0.88
#                 : 640. 正答率(テスト) = 0.8808
# Generation: 650. 正答率(トレーニング) = 0.91
#                 : 650. 正答率(テスト) = 0.8807
# Generation: 660. 正答率(トレーニング) = 0.88
#                 : 660. 正答率(テスト) = 0.881
# Generation: 670. 正答率(トレーニング) = 0.88
#                 : 670. 正答率(テスト) = 0.8816
# Generation: 680. 正答率(トレーニング) = 0.89
#                 : 680. 正答率(テスト) = 0.8835
# Generation: 690. 正答率(トレーニング) = 0.79
#                 : 690. 正答率(テスト) = 0.8866
# Generation: 700. 正答率(トレーニング) = 0.92
#                 : 700. 正答率(テスト) = 0.8859
# Generation: 710. 正答率(トレーニング) = 0.85
#                 : 710. 正答率(テスト) = 0.887
# Generation: 720. 正答率(トレーニング) = 0.95
#                 : 720. 正答率(テスト) = 0.887
# Generation: 730. 正答率(トレーニング) = 0.84
#                 : 730. 正答率(テスト) = 0.8883
# Generation: 740. 正答率(トレーニング) = 0.89
#                 : 740. 正答率(テスト) = 0.8897
# Generation: 750. 正答率(トレーニング) = 0.9
#                 : 750. 正答率(テスト) = 0.8901
# Generation: 760. 正答率(トレーニング) = 0.95
#                 : 760. 正答率(テスト) = 0.8898
# Generation: 770. 正答率(トレーニング) = 0.88
#                 : 770. 正答率(テスト) = 0.8901
# Generation: 780. 正答率(トレーニング) = 0.87
#                 : 780. 正答率(テスト) = 0.8897
# Generation: 790. 正答率(トレーニング) = 0.85
#                 : 790. 正答率(テスト) = 0.8892
# Generation: 800. 正答率(トレーニング) = 0.9
#                 : 800. 正答率(テスト) = 0.8906
# Generation: 810. 正答率(トレーニング) = 0.89
#                 : 810. 正答率(テスト) = 0.8922
# Generation: 820. 正答率(トレーニング) = 0.83
#                 : 820. 正答率(テスト) = 0.8929
# Generation: 830. 正答率(トレーニング) = 0.94
#                 : 830. 正答率(テスト) = 0.8927
# Generation: 840. 正答率(トレーニング) = 0.92
#                 : 840. 正答率(テスト) = 0.8949
# Generation: 850. 正答率(トレーニング) = 0.9
#                 : 850. 正答率(テスト) = 0.894
# Generation: 860. 正答率(トレーニング) = 0.91
#                 : 860. 正答率(テスト) = 0.8962
# Generation: 870. 正答率(トレーニング) = 0.81
#                 : 870. 正答率(テスト) = 0.8964
# Generation: 880. 正答率(トレーニング) = 0.91
#                 : 880. 正答率(テスト) = 0.8968
# Generation: 890. 正答率(トレーニング) = 0.93
#                 : 890. 正答率(テスト) = 0.8968
# Generation: 900. 正答率(トレーニング) = 0.91
#                 : 900. 正答率(テスト) = 0.8968
# Generation: 910. 正答率(トレーニング) = 0.92
#                 : 910. 正答率(テスト) = 0.8961
# Generation: 920. 正答率(トレーニング) = 0.9
#                 : 920. 正答率(テスト) = 0.8978
# Generation: 930. 正答率(トレーニング) = 0.88
#                 : 930. 正答率(テスト) = 0.8993
# Generation: 940. 正答率(トレーニング) = 0.85
#                 : 940. 正答率(テスト) = 0.8991
# Generation: 950. 正答率(トレーニング) = 0.88
#                 : 950. 正答率(テスト) = 0.8994
# Generation: 960. 正答率(トレーニング) = 0.9
#                 : 960. 正答率(テスト) = 0.8988
# Generation: 970. 正答率(トレーニング) = 0.88
#                 : 970. 正答率(テスト) = 0.8998
# Generation: 980. 正答率(トレーニング) = 0.95
#                 : 980. 正答率(テスト) = 0.9006
# Generation: 990. 正答率(トレーニング) = 0.91
#                 : 990. 正答率(テスト) = 0.8995
# Generation: 1000. 正答率(トレーニング) = 0.91
#                 : 1000. 正答率(テスト) = 0.9003
